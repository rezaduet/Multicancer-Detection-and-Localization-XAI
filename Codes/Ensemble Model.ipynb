# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.layers import Input, Lambda, Dense, Flatten,Dropout
from keras.models import Model
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import layers
from matplotlib.pyplot import figure
plt.style.use('ggplot')

# %%
def initiateGenerator(path):
    base_path = path
    print("\nTotal : ", end=" ")
    train_dataset = tf.keras.preprocessing.image_dataset_from_directory(batch_size=32, directory=base_path)

    train_datagen = ImageDataGenerator(validation_split=0.3)

    print("\nFor Training : ", end=" ")
    train_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical', subset='training')

    print("\nFor Val : ", end=" ")
    validation_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        subset='validation', shuffle=False)

    class_names = train_dataset.class_names
    noOfClasses = len(class_names)
    print("\nNo of Classes : ", noOfClasses)
    print("Classes : ", class_names)

    plt.figure(figsize=(10, 10))
    for images, labels in train_dataset.take(1):
        for i in range(noOfClasses):
            ax = plt.subplot(4, 4, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            plt.title(class_names[labels[i]])
            plt.axis("off")

    for image_batch, labels_batch in train_dataset:
        print("Image Shape : ",image_batch.shape)
        break
        
    return noOfClasses,class_names, train_generator, validation_generator

# %%
def initiateNormalize():
    AUTOTUNE = tf.data.AUTOTUNE

    train_ds = train_generator.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
    val_ds = val_generator.cache().prefetch(buffer_size=AUTOTUNE)
    normalization_layer = layers.Rescaling(1./255)

    normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
    image_batch, labels_batch = next(iter(normalized_ds))
    first_image = image_batch[0]
    print(np.min(first_image), np.max(first_image))

# %%
def plotOutput(history, className, epochs):
    figure(figsize=(10, 7), dpi=80)
    # plt.plot([1, 0], [0, 1], 'k--')
    plt.plot(history.history['accuracy'],label='Training_accuracy')
    plt.plot(history.history['val_accuracy'],label='Validation_accuracy')
    plt.plot(history.history['loss'],label='Training_loss')
    plt.plot(history.history['val_loss'],label='Validation_loss')
    plt.legend()
    plt.title('Training Accuracy vs Validation Accuracy & Training Loss vs Validation Loss')
    plt.xlabel('No.of epochs')
    plt.ylabel('Accuracy')
    plt.xlabel('Np.of epochs')
    plt.ylabel('Loss')
    plt.show()

# %%
def evalModel(model):
    evl = model.evaluate(validation_generator)
    acc = evl[1]*100
    msg=f'Accuracy on the Test Set = {acc:5.2f} %'
    print(msg)
    
def saveModel(model, className):
    model.save(className + " - VGG19.h5")
    print("Model Saved!")

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(15, 15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    plt.savefig(title + '.png')

# %%
def callPlot(model, className, classes):
    y_true = validation_generator.classes
    print("True : ", (y_true))

    y_pred = model.predict(validation_generator)
    y_pred = np.argmax(y_pred, axis=1)
    print("Predicted : ", (y_pred))

    conf_mat = confusion_matrix(y_true, y_pred)

    plot_confusion_matrix(cm           = conf_mat,
                          normalize    = False,
                          target_names = classes,
                          title        = className + "Confusion Matrix")

# %%
mpath = r'/content/drive/MyDrive/MCD'
classPaths = os.listdir(mpath)

IMAGE_SIZE = [224, 224]
img_height = 224
img_width = 224
noOfClasses = 0
gEpochs = 50
lr = 0.0001

for i in classPaths:
    print(i)
# Out:
# Training
# Confusion
# Dataset
# Code
# Best
# MCD RESULT.docx
# Model

# %%
className = 'Dataset'
cpath = os.path.join(mpath, 'Dataset')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
# Out:
# Total :  Found 8102 files belonging to 5 classes.
#
# For Training :  Found 5673 images belonging to 5 classes.
#
# For Val :  Found 2429 images belonging to 5 classes.
#
# No of Classes :  5
# Classes :  ['colon_aca', 'colon_bnt', 'lung_aca', 'lung_bnt', 'lung_scc']
# Image Shape :  (32, 256, 256, 3)

# %%
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Average
model_1 = load_model('/content/drive/MyDrive/MCD/Model/Dataset - VGG16.h5')
model_1 = Model(inputs=model_1.inputs,
                outputs=model_1.outputs,
                name='name_of_model_1')
model_2 = load_model('/content/drive/MyDrive/MCD/Model/Dataset - VGG19.h5')
model_2 = Model(inputs=model_2.inputs,
                outputs=model_2.outputs,
                name='name_of_model_2')
# model_3 = load_model('/content/drive/MyDrive/MCD/Model/Dataset - efficientnet.h5')
# model_3 = Model(inputs=model_3.inputs,
#                 outputs=model_3.outputs,
#                 name='name_of_model_3')
model_4 = load_model('/content/drive/MyDrive/MCD/Model/Dataset - resnet152.h5')
model_4 = Model(inputs=model_4.inputs,
                outputs=model_4.outputs,
                name='name_of_model_4')
model_5 = load_model('/content/drive/MyDrive/MCD/Model/Dataset - resnet50.h5')
model_5 = Model(inputs=model_5.inputs,
                outputs=model_5.outputs,
                name='name_of_model_5')
models = [model_1, model_2, model_4, model_5]
model_input = Input(shape=(224, 224, 3))
model_outputs = [model(model_input) for model in models]
ensemble_output = Average()(model_outputs)
ensemble_model = Model(inputs=model_input, outputs=ensemble_output, name='ensemble')

# %%
opt = tf.keras.optimizers.Adam(learning_rate=lr)

ensemble_model.compile(optimizer=opt,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

# %%
history = ensemble_model.fit(
      train_generator,
      validation_data=validation_generator,
      epochs=50,
      batch_size=16,
      #callbacks=[annealer, checkpoint],
      steps_per_epoch=len(train_generator),
      validation_steps=len(validation_generator)
    )
# Out:
# Epoch 1/50
# 178/178 [==============================] - 1601s 9s/step - loss: 0.0415 - accuracy: 0.9996 - val_loss: 0.0411 - val_accuracy: 0.9839
# Epoch 2/50
# 178/178 [==============================] - 157s 883ms/step - loss: 0.0394 - accuracy: 0.9998 - val_loss: 0.0381 - val_accuracy: 0.9860
# Epoch 3/50
# 178/178 [==============================] - 157s 879ms/step - loss: 0.0383 - accuracy: 0.9998 - val_loss: 0.0451 - val_accuracy: 0.9807
# Epoch 4/50
# 178/178 [==============================] - 156s 878ms/step - loss: 0.0384 - accuracy: 0.9996 - val_loss: 0.0420 - val_accuracy: 0.9856
# Epoch 5/50
# 178/178 [==============================] - 156s 877ms/step - loss: 0.0381 - accuracy: 0.9993 - val_loss: 0.0557 - val_accuracy: 0.9831
# Epoch 6/50
# 178/178 [==============================] - 156s 877ms/step - loss: 0.0372 - accuracy: 1.0000 - val_loss: 0.0522 - val_accuracy: 0.9864
# Epoch 7/50
# 178/178 [==============================] - 156s 877ms/step - loss: 0.0367 - accuracy: 1.0000 - val_loss: 0.0439 - val_accuracy: 0.9876
# Epoch 8/50
# 178/178 [==============================] - 156s 877ms/step - loss: 0.0390 - accuracy: 0.9998 - val_loss: 0.0464 - val_accuracy: 0.9864
# Epoch 9/50
# 178/178 [==============================] - 156s 876ms/step - loss: 0.0361 - accuracy: 0.9996 - val_loss: 0.0505 - val_accuracy: 0.9860
# Epoch 10/50
# 178/178 [==============================] - 156s 878ms/step - loss: 0.0355 - accuracy: 1.0000 - val_loss: 0.0476 - val_accuracy: 0.9831
# Epoch 11/50
# 178/178 [==============================] - 156s 876ms/step - loss: 0.0361 - accuracy: 0.9998 - val_loss: 0.0515 - val_accuracy: 0.9839
# Epoch 12/50
# 178/178 [==============================] - 156s 879ms/step - loss: 0.0349 - accuracy: 0.9998 - val_loss: 0.0502 - val_accuracy: 0.9839
# Epoch 13/50
# 178/178 [==============================] - 156s 877ms/step - loss: 0.0355 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 0.9856
# Epoch 14/50
# 178/178 [==============================] - 156s 877ms/step - loss: 0.0367 - accuracy: 0.9998 - val_loss: 0.0457 - val_accuracy: 0.9844
# Epoch 15/50
# 178/178 [==============================] - 156s 878ms/step - loss: 0.0375 - accuracy: 1.0000 - val_loss: 0.0424 - val_accuracy: 0.9852
# Epoch 16/50
# 178/178 [==============================] - 156s 877ms/step - loss: 0.0364 - accuracy: 1.0000 - val_loss: 0.0456 - val_accuracy: 0.9852
# Epoch 17/50
# 178/178 [==============================] - 156s 876ms/step - loss: 0.0345 - accuracy: 0.9998 - val_loss: 0.0659 - val_accuracy: 0.9831
# Epoch 18/50
# 178/178 [==============================] - 156s 877ms/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 0.0480 - val_accuracy: 0.9868
# Epoch 19/50
# 178/178 [==============================] - 156s 877ms/step - loss: 0.0343 - accuracy: 0.9998 - val_loss: 0.0450 - val_accuracy: 0.9848
# Epoch 20/50
# 178/178 [==============================] - 156s 878ms/step - loss: 0.0318 - accuracy: 1.0000 - val_loss: 0.0510 - val_accuracy: 0.9844
# Epoch 21/50
# 178/178 [==============================] - 156s 877ms/step - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.0501 - val_accuracy: 0.9864
# Epoch 22/50
# 178/178 [==============================] - 156s 877ms/step - loss: 0.0325 - accuracy: 0.9998 - val_loss: 0.0373 - val_accuracy: 0.9872
# Epoch 23/50
# 178/178 [==============================] - 156s 876ms/step - loss: 0.0338 - accuracy: 0.9996 - val_loss: 0.0451 - val_accuracy: 0.9848
# Epoch 24/50
# 178/178 [==============================] - 156s 877ms/step - loss: 0.0306 - accuracy: 0.9998 - val_loss: 0.0451 - val_accuracy: 0.9831
# Epoch 25/50
# 178/178 [==============================] - 156s 877ms/step - loss: 0.0304 - accuracy: 0.9998 - val_loss: 0.0503 - val_accuracy: 0.9864
# Epoch 26/50
# 178/178 [==============================] - 156s 878ms/step - loss: 0.0316 - accuracy: 0.9996 - val_loss: 0.0454 - val_accuracy: 0.9856
# Epoch 27/50
# 178/178 [==============================] - 156s 878ms/step - loss: 0.0312 - accuracy: 0.9998 - val_loss: 0.0405 - val_accuracy: 0.9860
# Epoch 28/50
# 178/178 [==============================] - 156s 878ms/step - loss: 0.0300 - accuracy: 1.0000 - val_loss: 0.0440 - val_accuracy: 0.9868
# Epoch 29/50
# 178/178 [==============================] - 156s 878ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.0453 - val_accuracy: 0.9848
# Epoch 30/50
# 178/178 [==============================] - 192s 1s/step - loss: 0.0308 - accuracy: 1.0000 - val_loss: 0.0526 - val_accuracy: 0.9872
# Epoch 31/50
# 178/178 [==============================] - 192s 1s/step - loss: 0.0311 - accuracy: 0.9995 - val_loss: 0.0538 - val_accuracy: 0.9864
# Epoch 32/50
# 178/178 [==============================] - 192s 1s/step - loss: 0.0304 - accuracy: 0.9996 - val_loss: 0.0668 - val_accuracy: 0.9881
# Epoch 33/50
# 178/178 [==============================] - 192s 1s/step - loss: 0.0299 - accuracy: 1.0000 - val_loss: 0.0559 - val_accuracy: 0.9872
# Epoch 34/50
# 178/178 [==============================] - 156s 878ms/step - loss: 0.0308 - accuracy: 0.9998 - val_loss: 0.0491 - val_accuracy: 0.9889
# Epoch 35/50
# 178/178 [==============================] - 156s 876ms/step - loss: 0.0284 - accuracy: 0.9998 - val_loss: 0.0571 - val_accuracy: 0.9872
# Epoch 36/50
# 178/178 [==============================] - 156s 878ms/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.0451 - val_accuracy: 0.9876
# Epoch 37/50
# 178/178 [==============================] - 156s 876ms/step - loss: 0.0280 - accuracy: 1.0000 - val_loss: 0.0536 - val_accuracy: 0.9868
# Epoch 38/50
# 178/178 [==============================] - 192s 1s/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 0.0570 - val_accuracy: 0.9872
# Epoch 39/50
# 178/178 [==============================] - 192s 1s/step - loss: 0.0291 - accuracy: 1.0000 - val_loss: 0.0508 - val_accuracy: 0.9868
# Epoch 40/50
# 178/178 [==============================] - 156s 878ms/step - loss: 0.0276 - accuracy: 0.9998 - val_loss: 0.0713 - val_accuracy: 0.9848
# Epoch 41/50
# 178/178 [==============================] - 192s 1s/step - loss: 0.0281 - accuracy: 0.9998 - val_loss: 0.0613 - val_accuracy: 0.9864
# Epoch 42/50
# 178/178 [==============================] - 192s 1s/step - loss: 0.0261 - accuracy: 1.0000 - val_loss: 0.0488 - val_accuracy: 0.9860
# Epoch 43/50
# 178/178 [==============================] - 156s 879ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.0508 - val_accuracy: 0.9864
# Epoch 44/50
# 178/178 [==============================] - 192s 1s/step - loss: 0.0298 - accuracy: 0.9998 - val_loss: 0.0557 - val_accuracy: 0.9881
# Epoch 45/50
# 178/178 [==============================] - 156s 878ms/step - loss: 0.0279 - accuracy: 1.0000 - val_loss: 0.0493 - val_accuracy: 0.9860
# Epoch 46/50
# 178/178 [==============================] - 156s 877ms/step - loss: 0.0268 - accuracy: 0.9996 - val_loss: 0.0595 - val_accuracy: 0.9864
# Epoch 47/50
# 178/178 [==============================] - 156s 877ms/step - loss: 0.0276 - accuracy: 0.9998 - val_loss: 0.0652 - val_accuracy: 0.9885
# Epoch 48/50
# 178/178 [==============================] - 156s 878ms/step - loss: 0.0289 - accuracy: 0.9996 - val_loss: 0.0384 - val_accuracy: 0.9868
# Epoch 49/50
# 178/178 [==============================] - 156s 878ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.0433 - val_accuracy: 0.9844
# Epoch 50/50
# 178/178 [==============================] - 156s 878ms/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.0452 - val_accuracy: 0.9860

# %%
plotOutput(history, className, gEpochs)
evalModel(ensemble_model)
saveModel(ensemble_model, className)
callPlot(ensemble_model, className, class_names)
# Out:
# 76/76 [==============================] - 47s 615ms/step - loss: 0.0452 - accuracy: 0.9860
# Accuracy on the Test Set = 98.60 %
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-256252651dce> in <module>
#       1 plotOutput(history, className, gEpochs)
#       2 evalModel(ensemble_model)
# ----> 3 saveModel(ensemble_model, className)
#       4 callPlot(ensemble_model, className, class_names)
#
# <ipython-input-8-403f1986612d> in saveModel(model, className)
#       6
#       7 def saveModel(model, className):
# ----> 8     model.save(className + " - VGG19.h5")
#       9     print("Model Saved!")
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.9/dist-packages/h5py/_hl/group.py in create_dataset(self, name, shape, dtype, data, **kwds)
#     181                     group = self.require_group(parent_path)
#     182
# --> 183             dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     184             dset = dataset.Dataset(dsid)
#     185             return dset
#
# /usr/local/lib/python3.9/dist-packages/h5py/_hl/dataset.py in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0)
#     163         sid = h5s.create_simple(shape, maxshape)
#     164
# --> 165     dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl, dapl=dapl)
#     166
#     167     if (data is not None) and (not isinstance(data, Empty)):
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5d.pyx in h5py.h5d.create()
#
# ValueError: Unable to create dataset (name already exists)
