# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.layers import Input, Lambda, Dense, Flatten,Dropout
from keras.models import Model
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import layers
from matplotlib.pyplot import figure
plt.style.use('ggplot')

# %%
def initiateGenerator(path):
    base_path = path
    print("\nTotal : ", end=" ")
    train_dataset = tf.keras.preprocessing.image_dataset_from_directory(batch_size=32, directory=base_path)

    train_datagen = ImageDataGenerator(validation_split=0.3)

    print("\nFor Training : ", end=" ")
    train_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical', subset='training')

    print("\nFor Val : ", end=" ")
    validation_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        subset='validation', shuffle=False)

    class_names = train_dataset.class_names
    noOfClasses = len(class_names)
    print("\nNo of Classes : ", noOfClasses)
    print("Classes : ", class_names)

    plt.figure(figsize=(10, 10))
    for images, labels in train_dataset.take(1):
        for i in range(noOfClasses):
            ax = plt.subplot(4, 4, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            plt.title(class_names[labels[i]])
            plt.axis("off")

    for image_batch, labels_batch in train_dataset:
        print("Image Shape : ",image_batch.shape)
        break
        
    return noOfClasses,class_names, train_generator, validation_generator

# %%
def initiateNormalize():
    AUTOTUNE = tf.data.AUTOTUNE

    train_ds = train_generator.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
    val_ds = val_generator.cache().prefetch(buffer_size=AUTOTUNE)
    normalization_layer = layers.Rescaling(1./255)

    normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
    image_batch, labels_batch = next(iter(normalized_ds))
    first_image = image_batch[0]
    print(np.min(first_image), np.max(first_image))

# %%
def initiateModel(noOfClasses,dropout):
    modelInput = tf.keras.applications.mobilenet.MobileNet(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    for layer in modelInput.layers:
        layer.trainable = False
    
    x = Flatten()(modelInput.output)
    x=Dense(32,activation='relu')(x)
    x=Dropout(dropout)(x)
    prediction = Dense(noOfClasses, activation='softmax')(x)

    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

def modelSummary(model):
    model.summary()

# %%
def initiateParams(className, model, lr):
    opt = tf.keras.optimizers.Adam(learning_rate=lr)

    model.compile(optimizer=opt,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
    checkpoint = ModelCheckpoint(className + 'VGG16.h5', verbose=1, save_best_only=True)
    
    return model, annealer, checkpoint

# %%
def modelFit(model, annealer, checkpoint, epochs=20, batchSize = 16):

    history = model.fit(
      train_generator,
      validation_data=validation_generator,
      epochs=epochs,
      batch_size=batchSize,
      #callbacks=[annealer, checkpoint],
      steps_per_epoch=len(train_generator),
      validation_steps=len(validation_generator)
    )
    
    return history

# %%
def plotOutput(history, className, epochs):
    figure(figsize=(10, 7), dpi=80)
    # plt.plot([1, 0], [0, 1], 'k--')
    plt.plot(history.history['accuracy'],label='Training_accuracy')
    plt.plot(history.history['val_accuracy'],label='Validation_accuracy')
    plt.plot(history.history['loss'],label='Training_loss')
    plt.plot(history.history['val_loss'],label='Validation_loss')
    plt.legend()
    plt.title('Training Accuracy vs Validation Accuracy & Training Loss vs Validation Loss')
    plt.xlabel('No.of epochs')
    plt.ylabel('Accuracy')
    plt.xlabel('Np.of epochs')
    plt.ylabel('Loss')
    plt.show()

# %%
def evalModel(model):
    evl = model.evaluate(validation_generator)
    acc = evl[1]*100
    msg=f'Accuracy on the Test Set = {acc:5.2f} %'
    print(msg)
    
def saveModel(model, className):
    model.save(className + " - VGG16.h5")
    print("Model Saved!")

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(15, 15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    plt.savefig(title + '.png')

# %%
def callPlot(model, className, classes):
    y_true = validation_generator.classes
    print("True : ", (y_true))

    y_pred = model.predict(validation_generator)
    y_pred = np.argmax(y_pred, axis=1)
    print("Predicted : ", (y_pred))

    conf_mat = confusion_matrix(y_true, y_pred)

    plot_confusion_matrix(cm           = conf_mat,
                          normalize    = False,
                          target_names = classes,
                          title        = className + "Confusion Matrix")

# %%
mpath = r'/content/drive/MyDrive/Lung and Colon'
classPaths = os.listdir(mpath)

IMAGE_SIZE = [224, 224]
img_height = 224
img_width = 224
noOfClasses = 0
gEpochs = 50
lr = 0.0001

for i in classPaths:
    print(i)
# Out:
# Dataset
# code

# %%
className = 'Dataset'
cpath = os.path.join(mpath, 'Dataset')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
# Out:
# Total :  Found 8102 files belonging to 5 classes.
#
# For Training :  Found 5673 images belonging to 5 classes.
#
# For Val :  Found 2429 images belonging to 5 classes.
#
# No of Classes :  5
# Classes :  ['colon_aca', 'colon_bnt', 'lung_aca', 'lung_bnt', 'lung_scc']
# Image Shape :  (32, 256, 256, 3)

# %%
batch_size = [16]
dropout = [0.3,0.5]

# %%
for i in range(1):
  for j in range(2):
    curModel = initiateModel(noOfClasses,dropout[j])
    modelSummary(curModel)
    curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
    curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=batch_size[i])
    plotOutput(curHistory, className, gEpochs)
    evalModel(curModel)
    # saveModel(curModel, className)
    callPlot(curModel, className, class_names)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 2s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 112, 112, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 112, 112, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 112, 112, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 56, 56, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 56, 56, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 57, 57, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 28, 28, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 28, 28, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 28, 28, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 28, 28, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 29, 29, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)      2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 14, 14, 256)      1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 14, 14, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 14, 14, 512)       131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)      0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 7, 7, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 7, 7, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 7, 7, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 32)                1605664
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 4,834,693
# Trainable params: 1,605,829
# Non-trainable params: 3,228,864
# _________________________________________________________________
# Epoch 1/50
# 178/178 [==============================] - 3771s 21s/step - loss: 0.5949 - accuracy: 0.7562 - val_loss: 0.2393 - val_accuracy: 0.9041
# Epoch 2/50
# 178/178 [==============================] - 57s 323ms/step - loss: 0.3316 - accuracy: 0.8692 - val_loss: 0.2128 - val_accuracy: 0.9214
# Epoch 3/50
# 178/178 [==============================] - 57s 321ms/step - loss: 0.2633 - accuracy: 0.8955 - val_loss: 0.1782 - val_accuracy: 0.9300
# Epoch 4/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.2133 - accuracy: 0.9136 - val_loss: 0.1789 - val_accuracy: 0.9242
# Epoch 5/50
# 178/178 [==============================] - 56s 317ms/step - loss: 0.1887 - accuracy: 0.9281 - val_loss: 0.1562 - val_accuracy: 0.9366
# Epoch 6/50
# 178/178 [==============================] - 60s 340ms/step - loss: 0.1700 - accuracy: 0.9334 - val_loss: 0.1605 - val_accuracy: 0.9358
# Epoch 7/50
# 178/178 [==============================] - 56s 317ms/step - loss: 0.1578 - accuracy: 0.9374 - val_loss: 0.1741 - val_accuracy: 0.9271
# Epoch 8/50
# 178/178 [==============================] - 56s 316ms/step - loss: 0.1436 - accuracy: 0.9445 - val_loss: 0.1683 - val_accuracy: 0.9296
# Epoch 9/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.1317 - accuracy: 0.9491 - val_loss: 0.1394 - val_accuracy: 0.9420
# Epoch 10/50
# 178/178 [==============================] - 56s 313ms/step - loss: 0.1176 - accuracy: 0.9563 - val_loss: 0.1393 - val_accuracy: 0.9428
# Epoch 11/50
# 178/178 [==============================] - 56s 314ms/step - loss: 0.1103 - accuracy: 0.9593 - val_loss: 0.1425 - val_accuracy: 0.9411
# Epoch 12/50
# 178/178 [==============================] - 56s 315ms/step - loss: 0.1155 - accuracy: 0.9586 - val_loss: 0.1371 - val_accuracy: 0.9448
# Epoch 13/50
# 178/178 [==============================] - 56s 314ms/step - loss: 0.1002 - accuracy: 0.9632 - val_loss: 0.1595 - val_accuracy: 0.9411
# Epoch 14/50
# 178/178 [==============================] - 57s 321ms/step - loss: 0.0933 - accuracy: 0.9662 - val_loss: 0.1559 - val_accuracy: 0.9391
# Epoch 15/50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.0937 - accuracy: 0.9665 - val_loss: 0.1376 - val_accuracy: 0.9510
# Epoch 16/50
# 178/178 [==============================] - 56s 317ms/step - loss: 0.0874 - accuracy: 0.9684 - val_loss: 0.1409 - val_accuracy: 0.9473
# Epoch 17/50
# 178/178 [==============================] - 55s 311ms/step - loss: 0.0840 - accuracy: 0.9704 - val_loss: 0.1466 - val_accuracy: 0.9481
# Epoch 18/50
# 178/178 [==============================] - 57s 320ms/step - loss: 0.0887 - accuracy: 0.9669 - val_loss: 0.1534 - val_accuracy: 0.9362
# Epoch 19/50
# 178/178 [==============================] - 56s 315ms/step - loss: 0.0900 - accuracy: 0.9655 - val_loss: 0.1584 - val_accuracy: 0.9457
# Epoch 20/50
# 178/178 [==============================] - 55s 312ms/step - loss: 0.0838 - accuracy: 0.9699 - val_loss: 0.1469 - val_accuracy: 0.9481
# Epoch 21/50
# 178/178 [==============================] - 55s 310ms/step - loss: 0.0659 - accuracy: 0.9764 - val_loss: 0.1378 - val_accuracy: 0.9510
# Epoch 22/50
# 178/178 [==============================] - 55s 312ms/step - loss: 0.0667 - accuracy: 0.9771 - val_loss: 0.1459 - val_accuracy: 0.9473
# Epoch 23/50
# 178/178 [==============================] - 57s 321ms/step - loss: 0.0670 - accuracy: 0.9759 - val_loss: 0.1733 - val_accuracy: 0.9440
# Epoch 24/50
# 178/178 [==============================] - 59s 334ms/step - loss: 0.0681 - accuracy: 0.9762 - val_loss: 0.1745 - val_accuracy: 0.9494
# Epoch 25/50
# 178/178 [==============================] - 55s 312ms/step - loss: 0.0578 - accuracy: 0.9792 - val_loss: 0.1565 - val_accuracy: 0.9510
# Epoch 26/50
# 178/178 [==============================] - 55s 311ms/step - loss: 0.0671 - accuracy: 0.9773 - val_loss: 0.1567 - val_accuracy: 0.9514
# Epoch 27/50
# 178/178 [==============================] - 56s 313ms/step - loss: 0.0620 - accuracy: 0.9788 - val_loss: 0.1599 - val_accuracy: 0.9506
# Epoch 28/50
# 178/178 [==============================] - 57s 320ms/step - loss: 0.0670 - accuracy: 0.9764 - val_loss: 0.1820 - val_accuracy: 0.9378
# Epoch 29/50
# 178/178 [==============================] - 60s 337ms/step - loss: 0.0587 - accuracy: 0.9808 - val_loss: 0.1679 - val_accuracy: 0.9461
# Epoch 30/50
# 178/178 [==============================] - 56s 314ms/step - loss: 0.0560 - accuracy: 0.9799 - val_loss: 0.1811 - val_accuracy: 0.9432
# Epoch 31/50
# 178/178 [==============================] - 56s 314ms/step - loss: 0.0523 - accuracy: 0.9810 - val_loss: 0.1820 - val_accuracy: 0.9481
# Epoch 32/50
# 178/178 [==============================] - 57s 321ms/step - loss: 0.0462 - accuracy: 0.9850 - val_loss: 0.1816 - val_accuracy: 0.9498
# Epoch 33/50
# 178/178 [==============================] - 55s 312ms/step - loss: 0.0472 - accuracy: 0.9841 - val_loss: 0.1810 - val_accuracy: 0.9432
# Epoch 34/50
# 178/178 [==============================] - 56s 317ms/step - loss: 0.0560 - accuracy: 0.9818 - val_loss: 0.1789 - val_accuracy: 0.9399
# Epoch 35/50
# 178/178 [==============================] - 56s 314ms/step - loss: 0.0589 - accuracy: 0.9794 - val_loss: 0.1665 - val_accuracy: 0.9514
# Epoch 36/50
# 178/178 [==============================] - 60s 338ms/step - loss: 0.0532 - accuracy: 0.9818 - val_loss: 0.1607 - val_accuracy: 0.9498
# Epoch 37/50
# 178/178 [==============================] - 56s 317ms/step - loss: 0.0544 - accuracy: 0.9801 - val_loss: 0.1941 - val_accuracy: 0.9444
# Epoch 38/50
# 178/178 [==============================] - 55s 310ms/step - loss: 0.0521 - accuracy: 0.9811 - val_loss: 0.2031 - val_accuracy: 0.9420
# Epoch 39/50
# 178/178 [==============================] - 56s 314ms/step - loss: 0.0555 - accuracy: 0.9785 - val_loss: 0.1765 - val_accuracy: 0.9469
# Epoch 40/50
# 178/178 [==============================] - 56s 315ms/step - loss: 0.0479 - accuracy: 0.9847 - val_loss: 0.1850 - val_accuracy: 0.9502
# Epoch 41/50
# 178/178 [==============================] - 56s 314ms/step - loss: 0.0482 - accuracy: 0.9834 - val_loss: 0.1731 - val_accuracy: 0.9502
# Epoch 42/50
# 178/178 [==============================] - 57s 319ms/step - loss: 0.0401 - accuracy: 0.9859 - val_loss: 0.2147 - val_accuracy: 0.9510
# Epoch 43/50
# 178/178 [==============================] - 60s 339ms/step - loss: 0.0502 - accuracy: 0.9836 - val_loss: 0.2010 - val_accuracy: 0.9510
# Epoch 44/50
# 178/178 [==============================] - 55s 310ms/step - loss: 0.0530 - accuracy: 0.9813 - val_loss: 0.2065 - val_accuracy: 0.9461
# Epoch 45/50
# 178/178 [==============================] - 55s 311ms/step - loss: 0.0493 - accuracy: 0.9815 - val_loss: 0.2307 - val_accuracy: 0.9411
# Epoch 46/50
# 178/178 [==============================] - 55s 311ms/step - loss: 0.0393 - accuracy: 0.9871 - val_loss: 0.2177 - val_accuracy: 0.9506
# Epoch 47/50
# 178/178 [==============================] - 57s 321ms/step - loss: 0.0443 - accuracy: 0.9847 - val_loss: 0.2253 - val_accuracy: 0.9481
# Epoch 48/50
# 178/178 [==============================] - 55s 311ms/step - loss: 0.0512 - accuracy: 0.9827 - val_loss: 0.2361 - val_accuracy: 0.9403
# Epoch 49/50
# 178/178 [==============================] - 55s 312ms/step - loss: 0.0404 - accuracy: 0.9859 - val_loss: 0.2552 - val_accuracy: 0.9411
# Epoch 50/50
# 178/178 [==============================] - 56s 317ms/step - loss: 0.0432 - accuracy: 0.9845 - val_loss: 0.2186 - val_accuracy: 0.9494
# 76/76 [==============================] - 16s 216ms/step - loss: 0.2186 - accuracy: 0.9494
# Accuracy on the Test Set = 94.94 %
# True :  [0 0 0 ... 4 4 4]
# 76/76 [==============================] - 17s 217ms/step
# Predicted :  [0 0 0 ... 4 4 4]
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 112, 112, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 112, 112, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 112, 112, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 56, 56, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 56, 56, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 57, 57, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 28, 28, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 28, 28, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 28, 28, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 28, 28, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 29, 29, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)      2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 14, 14, 256)      1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 14, 14, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 14, 14, 512)       131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)      0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 7, 7, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 7, 7, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 7, 7, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  flatten_1 (Flatten)         (None, 50176)             0
#
#  dense_2 (Dense)             (None, 32)                1605664
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 4,834,693
# Trainable params: 1,605,829
# Non-trainable params: 3,228,864
# _________________________________________________________________
# Epoch 1/50
# 178/178 [==============================] - 61s 328ms/step - loss: 0.8495 - accuracy: 0.6399 - val_loss: 0.3936 - val_accuracy: 0.8728
# Epoch 2/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.6227 - accuracy: 0.7206 - val_loss: 0.3037 - val_accuracy: 0.9020
# Epoch 3/50
# 178/178 [==============================] - 55s 312ms/step - loss: 0.5371 - accuracy: 0.7557 - val_loss: 0.2562 - val_accuracy: 0.9189
# Epoch 4/50
# 178/178 [==============================] - 56s 313ms/step - loss: 0.5063 - accuracy: 0.7742 - val_loss: 0.2310 - val_accuracy: 0.9280
# Epoch 5/50
# 178/178 [==============================] - 61s 340ms/step - loss: 0.4657 - accuracy: 0.7804 - val_loss: 0.2431 - val_accuracy: 0.9185
# Epoch 6/50
# 178/178 [==============================] - 55s 312ms/step - loss: 0.4615 - accuracy: 0.7767 - val_loss: 0.2091 - val_accuracy: 0.9263
# Epoch 7/50
# 178/178 [==============================] - 56s 313ms/step - loss: 0.4358 - accuracy: 0.7978 - val_loss: 0.1837 - val_accuracy: 0.9312
# Epoch 8/50
# 178/178 [==============================] - 56s 312ms/step - loss: 0.4086 - accuracy: 0.8098 - val_loss: 0.1802 - val_accuracy: 0.9337
# Epoch 9/50
# 178/178 [==============================] - 57s 321ms/step - loss: 0.4042 - accuracy: 0.8100 - val_loss: 0.1738 - val_accuracy: 0.9350
# Epoch 10/50
# 178/178 [==============================] - 56s 312ms/step - loss: 0.3956 - accuracy: 0.8057 - val_loss: 0.1679 - val_accuracy: 0.9341
# Epoch 11/50
# 178/178 [==============================] - 56s 313ms/step - loss: 0.3776 - accuracy: 0.8147 - val_loss: 0.1752 - val_accuracy: 0.9304
# Epoch 12/50
# 178/178 [==============================] - 56s 314ms/step - loss: 0.3846 - accuracy: 0.8128 - val_loss: 0.1634 - val_accuracy: 0.9399
# Epoch 13/50
# 178/178 [==============================] - 56s 314ms/step - loss: 0.3558 - accuracy: 0.8251 - val_loss: 0.1679 - val_accuracy: 0.9374
# Epoch 14/50
# 178/178 [==============================] - 57s 319ms/step - loss: 0.3460 - accuracy: 0.8295 - val_loss: 0.1645 - val_accuracy: 0.9403
# Epoch 15/50
# 178/178 [==============================] - 56s 314ms/step - loss: 0.3411 - accuracy: 0.8274 - val_loss: 0.1656 - val_accuracy: 0.9378
# Epoch 16/50
# 178/178 [==============================] - 55s 310ms/step - loss: 0.3308 - accuracy: 0.8354 - val_loss: 0.1517 - val_accuracy: 0.9424
# Epoch 17/50
# 178/178 [==============================] - 56s 313ms/step - loss: 0.3442 - accuracy: 0.8276 - val_loss: 0.1623 - val_accuracy: 0.9420
# Epoch 18/50
# 178/178 [==============================] - 55s 308ms/step - loss: 0.3381 - accuracy: 0.8264 - val_loss: 0.1615 - val_accuracy: 0.9370
# Epoch 19/50
# 178/178 [==============================] - 57s 321ms/step - loss: 0.3260 - accuracy: 0.8359 - val_loss: 0.1540 - val_accuracy: 0.9461
# Epoch 20/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.3326 - accuracy: 0.8331 - val_loss: 0.1777 - val_accuracy: 0.9370
# Epoch 21/50
# 178/178 [==============================] - 55s 310ms/step - loss: 0.3226 - accuracy: 0.8350 - val_loss: 0.1537 - val_accuracy: 0.9420
# Epoch 22/50
# 178/178 [==============================] - 56s 313ms/step - loss: 0.3234 - accuracy: 0.8366 - val_loss: 0.1540 - val_accuracy: 0.9374
# Epoch 23/50
# 178/178 [==============================] - 57s 319ms/step - loss: 0.3165 - accuracy: 0.8421 - val_loss: 0.1540 - val_accuracy: 0.9461
# Epoch 24/50
# 178/178 [==============================] - 56s 317ms/step - loss: 0.3191 - accuracy: 0.8429 - val_loss: 0.1607 - val_accuracy: 0.9457
# Epoch 25/50
# 178/178 [==============================] - 57s 319ms/step - loss: 0.3031 - accuracy: 0.8569 - val_loss: 0.1568 - val_accuracy: 0.9457
# Epoch 26/50
# 178/178 [==============================] - 55s 309ms/step - loss: 0.3098 - accuracy: 0.8549 - val_loss: 0.1522 - val_accuracy: 0.9448
# Epoch 27/50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.3009 - accuracy: 0.8562 - val_loss: 0.1949 - val_accuracy: 0.9399
# Epoch 28/50
# 178/178 [==============================] - 55s 312ms/step - loss: 0.2950 - accuracy: 0.8627 - val_loss: 0.1807 - val_accuracy: 0.9424
# Epoch 29/50
# 178/178 [==============================] - 57s 318ms/step - loss: 0.2871 - accuracy: 0.8625 - val_loss: 0.1698 - val_accuracy: 0.9461
# Epoch 30/50
# 178/178 [==============================] - 56s 315ms/step - loss: 0.2865 - accuracy: 0.8652 - val_loss: 0.1655 - val_accuracy: 0.9457
# Epoch 31/50
# 178/178 [==============================] - 55s 311ms/step - loss: 0.2874 - accuracy: 0.8630 - val_loss: 0.1770 - val_accuracy: 0.9444
# Epoch 32/50
# 178/178 [==============================] - 55s 311ms/step - loss: 0.2947 - accuracy: 0.8583 - val_loss: 0.1750 - val_accuracy: 0.9440
# Epoch 33/50
# 178/178 [==============================] - 55s 309ms/step - loss: 0.2744 - accuracy: 0.8722 - val_loss: 0.1549 - val_accuracy: 0.9465
# Epoch 34/50
# 178/178 [==============================] - 55s 309ms/step - loss: 0.2849 - accuracy: 0.8627 - val_loss: 0.1566 - val_accuracy: 0.9506
# Epoch 35/50
# 178/178 [==============================] - 55s 311ms/step - loss: 0.2733 - accuracy: 0.8692 - val_loss: 0.1508 - val_accuracy: 0.9473
# Epoch 36/50
# 178/178 [==============================] - 55s 310ms/step - loss: 0.2594 - accuracy: 0.8793 - val_loss: 0.1770 - val_accuracy: 0.9424
# Epoch 37/50
# 178/178 [==============================] - 55s 309ms/step - loss: 0.2792 - accuracy: 0.8662 - val_loss: 0.2244 - val_accuracy: 0.9329
# Epoch 38/50
# 178/178 [==============================] - 57s 318ms/step - loss: 0.2627 - accuracy: 0.8757 - val_loss: 0.1544 - val_accuracy: 0.9469
# Epoch 39/50
# 178/178 [==============================] - 55s 312ms/step - loss: 0.2749 - accuracy: 0.8660 - val_loss: 0.2058 - val_accuracy: 0.9440
# Epoch 40/50
# 178/178 [==============================] - 55s 311ms/step - loss: 0.2753 - accuracy: 0.8699 - val_loss: 0.1596 - val_accuracy: 0.9485
# Epoch 41/50
# 178/178 [==============================] - 55s 311ms/step - loss: 0.2642 - accuracy: 0.8741 - val_loss: 0.1612 - val_accuracy: 0.9465
# Epoch 42/50
# 178/178 [==============================] - 55s 309ms/step - loss: 0.2533 - accuracy: 0.8805 - val_loss: 0.1707 - val_accuracy: 0.9502
# Epoch 43/50
# 178/178 [==============================] - 56s 318ms/step - loss: 0.2666 - accuracy: 0.8694 - val_loss: 0.1922 - val_accuracy: 0.9415
# Epoch 44/50
# 178/178 [==============================] - 55s 308ms/step - loss: 0.2716 - accuracy: 0.8655 - val_loss: 0.1717 - val_accuracy: 0.9506
# Epoch 45/50
# 178/178 [==============================] - 55s 308ms/step - loss: 0.2467 - accuracy: 0.8793 - val_loss: 0.1860 - val_accuracy: 0.9444
# Epoch 46/50
# 178/178 [==============================] - 55s 309ms/step - loss: 0.2610 - accuracy: 0.8715 - val_loss: 0.1749 - val_accuracy: 0.9477
# Epoch 47/50
# 178/178 [==============================] - 56s 315ms/step - loss: 0.2554 - accuracy: 0.8766 - val_loss: 0.1801 - val_accuracy: 0.9481
# Epoch 48/50
# 178/178 [==============================] - 55s 309ms/step - loss: 0.2506 - accuracy: 0.8819 - val_loss: 0.1790 - val_accuracy: 0.9481
# Epoch 49/50
# 178/178 [==============================] - 55s 309ms/step - loss: 0.2582 - accuracy: 0.8780 - val_loss: 0.2080 - val_accuracy: 0.9465
# Epoch 50/50
# 178/178 [==============================] - 55s 310ms/step - loss: 0.2426 - accuracy: 0.8815 - val_loss: 0.2148 - val_accuracy: 0.9469
# 76/76 [==============================] - 17s 229ms/step - loss: 0.2148 - accuracy: 0.9469
# Accuracy on the Test Set = 94.69 %
# True :  [0 0 0 ... 4 4 4]
# 76/76 [==============================] - 17s 219ms/step
# Predicted :  [0 0 0 ... 4 2 4]
