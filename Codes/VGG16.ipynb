# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.layers import Input, Lambda, Dense, Flatten,Dropout
from keras.models import Model
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import layers
from matplotlib.pyplot import figure
plt.style.use('ggplot')

# %%
def initiateGenerator(path):
    base_path = path
    print("\nTotal : ", end=" ")
    train_dataset = tf.keras.preprocessing.image_dataset_from_directory(batch_size=32, directory=base_path)

    train_datagen = ImageDataGenerator(validation_split=0.3)

    print("\nFor Training : ", end=" ")
    train_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical', subset='training')

    print("\nFor Val : ", end=" ")
    validation_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        subset='validation', shuffle=False)

    class_names = train_dataset.class_names
    noOfClasses = len(class_names)
    print("\nNo of Classes : ", noOfClasses)
    print("Classes : ", class_names)

    plt.figure(figsize=(10, 10))
    for images, labels in train_dataset.take(1):
        for i in range(noOfClasses):
            ax = plt.subplot(4, 4, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            plt.title(class_names[labels[i]])
            plt.axis("off")

    for image_batch, labels_batch in train_dataset:
        print("Image Shape : ",image_batch.shape)
        break
        
    return noOfClasses,class_names, train_generator, validation_generator

# %%
def initiateNormalize():
    AUTOTUNE = tf.data.AUTOTUNE

    train_ds = train_generator.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
    val_ds = val_generator.cache().prefetch(buffer_size=AUTOTUNE)
    normalization_layer = layers.Rescaling(1./255)

    normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
    image_batch, labels_batch = next(iter(normalized_ds))
    first_image = image_batch[0]
    print(np.min(first_image), np.max(first_image))

# %%
def initiateModel(noOfClasses,dropout):
    modelInput = tf.keras.applications.VGG16(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    for layer in modelInput.layers:
        layer.trainable = False
    
    x = Flatten()(modelInput.output)
    x=Dense(32,activation='relu')(x)
    x=Dropout(dropout)(x)
    prediction = Dense(noOfClasses, activation='softmax')(x)

    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

def modelSummary(model):
    model.summary()

# %%
def initiateParams(className, model, lr):
    opt = tf.keras.optimizers.Adam(learning_rate=lr)

    model.compile(optimizer=opt,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
    checkpoint = ModelCheckpoint(className + 'VGG16.h5', verbose=1, save_best_only=True)
    
    return model, annealer, checkpoint

# %%
def modelFit(model, annealer, checkpoint, epochs=20, batchSize = 16):

    history = model.fit(
      train_generator,
      validation_data=validation_generator,
      epochs=epochs,
      batch_size=batchSize,
      #callbacks=[annealer, checkpoint],
      steps_per_epoch=len(train_generator),
      validation_steps=len(validation_generator)
    )
    
    return history

# %%
def plotOutput(history, className, epochs):
    figure(figsize=(10, 7), dpi=80)
    # plt.plot([1, 0], [0, 1], 'k--')
    plt.plot(history.history['accuracy'],label='Training_accuracy')
    plt.plot(history.history['val_accuracy'],label='Validation_accuracy')
    plt.plot(history.history['loss'],label='Training_loss')
    plt.plot(history.history['val_loss'],label='Validation_loss')
    plt.legend()
    plt.title('Training Accuracy vs Validation Accuracy & Training Loss vs Validation Loss')
    plt.xlabel('No.of epochs')
    plt.ylabel('Accuracy')
    plt.xlabel('Np.of epochs')
    plt.ylabel('Loss')
    plt.show()

# %%
def evalModel(model):
    evl = model.evaluate(validation_generator)
    acc = evl[1]*100
    msg=f'Accuracy on the Test Set = {acc:5.2f} %'
    print(msg)
    
def saveModel(model, className):
    model.save(className + " - VGG16.h5")
    print("Model Saved!")

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(15, 15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    plt.savefig(title + '.png')

# %%
def callPlot(model, className, classes):
    y_true = validation_generator.classes
    print("True : ", (y_true))

    y_pred = model.predict(validation_generator)
    y_pred = np.argmax(y_pred, axis=1)
    print("Predicted : ", (y_pred))

    conf_mat = confusion_matrix(y_true, y_pred)

    plot_confusion_matrix(cm           = conf_mat,
                          normalize    = False,
                          target_names = classes,
                          title        = className + "Confusion Matrix")

# %%
mpath = r'/content/drive/MyDrive/Lung and Colon'
classPaths = os.listdir(mpath)

IMAGE_SIZE = [224, 224]
img_height = 224
img_width = 224
noOfClasses = 0
gEpochs = 50
lr = 0.0001

for i in classPaths:
    print(i)
# Out:
# Dataset
# code

# %%
className = 'Dataset'
cpath = os.path.join(mpath, 'Dataset')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
# Out:
# Total :  Found 8102 files belonging to 5 classes.
#
# For Training :  Found 5673 images belonging to 5 classes.
#
# For Val :  Found 2429 images belonging to 5 classes.
#
# No of Classes :  5
# Classes :  ['colon_aca', 'colon_bnt', 'lung_aca', 'lung_bnt', 'lung_scc']
# Image Shape :  (32, 256, 256, 3)

# %%
batch_size = [16,32]
dropout = [0.3,0.5]

# %%
for i in range(2):
  for j in range(2):
    curModel = initiateModel(noOfClasses,dropout[j])
    modelSummary(curModel)
    curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
    curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=batch_size[i])
    plotOutput(curHistory, className, gEpochs)
    evalModel(curModel)
    saveModel(curModel, className)
    callPlot(curModel, className, class_names)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 32)                802848
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 15,517,701
# Trainable params: 803,013
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/50
# 178/178 [==============================] - 2171s 12s/step - loss: 1.2444 - accuracy: 0.6723 - val_loss: 0.3884 - val_accuracy: 0.8806
# Epoch 2/50
# 178/178 [==============================] - 61s 341ms/step - loss: 0.4259 - accuracy: 0.8267 - val_loss: 0.2535 - val_accuracy: 0.9201
# Epoch 3/50
# 178/178 [==============================] - 60s 334ms/step - loss: 0.3009 - accuracy: 0.8747 - val_loss: 0.2027 - val_accuracy: 0.9321
# Epoch 4/50
# 178/178 [==============================] - 63s 355ms/step - loss: 0.2436 - accuracy: 0.8928 - val_loss: 0.1944 - val_accuracy: 0.9354
# Epoch 5/50
# 178/178 [==============================] - 60s 337ms/step - loss: 0.2055 - accuracy: 0.9105 - val_loss: 0.1802 - val_accuracy: 0.9494
# Epoch 6/50
# 178/178 [==============================] - 63s 354ms/step - loss: 0.1766 - accuracy: 0.9224 - val_loss: 0.1844 - val_accuracy: 0.9518
# Epoch 7/50
# 178/178 [==============================] - 60s 339ms/step - loss: 0.1393 - accuracy: 0.9355 - val_loss: 0.1441 - val_accuracy: 0.9543
# Epoch 8/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.1317 - accuracy: 0.9394 - val_loss: 0.1549 - val_accuracy: 0.9580
# Epoch 9/50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.1158 - accuracy: 0.9475 - val_loss: 0.1825 - val_accuracy: 0.9605
# Epoch 10/50
# 178/178 [==============================] - 61s 341ms/step - loss: 0.0942 - accuracy: 0.9646 - val_loss: 0.1853 - val_accuracy: 0.9580
# Epoch 11/50
# 178/178 [==============================] - 60s 337ms/step - loss: 0.0964 - accuracy: 0.9676 - val_loss: 0.1627 - val_accuracy: 0.9634
# Epoch 12/50
# 178/178 [==============================] - 63s 355ms/step - loss: 0.0868 - accuracy: 0.9653 - val_loss: 0.1885 - val_accuracy: 0.9617
# Epoch 13/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.0841 - accuracy: 0.9688 - val_loss: 0.1564 - val_accuracy: 0.9662
# Epoch 14/50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.0836 - accuracy: 0.9730 - val_loss: 0.1674 - val_accuracy: 0.9658
# Epoch 15/50
# 178/178 [==============================] - 61s 340ms/step - loss: 0.0741 - accuracy: 0.9729 - val_loss: 0.1683 - val_accuracy: 0.9667
# Epoch 16/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.0758 - accuracy: 0.9709 - val_loss: 0.1399 - val_accuracy: 0.9687
# Epoch 17/50
# 178/178 [==============================] - 63s 356ms/step - loss: 0.0635 - accuracy: 0.9767 - val_loss: 0.1635 - val_accuracy: 0.9650
# Epoch 18/50
# 178/178 [==============================] - 60s 337ms/step - loss: 0.0634 - accuracy: 0.9771 - val_loss: 0.1683 - val_accuracy: 0.9625
# Epoch 19/50
# 178/178 [==============================] - 63s 354ms/step - loss: 0.0642 - accuracy: 0.9796 - val_loss: 0.1757 - val_accuracy: 0.9691
# Epoch 20/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.0622 - accuracy: 0.9783 - val_loss: 0.1815 - val_accuracy: 0.9691
# Epoch 21/50
# 178/178 [==============================] - 63s 355ms/step - loss: 0.0583 - accuracy: 0.9787 - val_loss: 0.1447 - val_accuracy: 0.9699
# Epoch 22/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.0618 - accuracy: 0.9781 - val_loss: 0.1274 - val_accuracy: 0.9654
# Epoch 23/50
# 178/178 [==============================] - 62s 351ms/step - loss: 0.0481 - accuracy: 0.9831 - val_loss: 0.1516 - val_accuracy: 0.9679
# Epoch 24/50
# 178/178 [==============================] - 59s 333ms/step - loss: 0.
50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.0971 - accuracy: 0.9612 - val_loss: 0.1476 - val_accuracy: 0.9675
# Epoch 14/50
# 178/178 [==============================] - 63s 352ms/step - loss: 0.0769 - accuracy: 0.9702 - val_loss: 0.1578 - val_accuracy: 0.9699
# Epoch 15/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.0756 - accuracy: 0.9699 - val_loss: 0.1830 - val_accuracy: 0.9704
# Epoch 16/50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.0699 - accuracy: 0.9764 - val_loss: 0.1682 - val_accuracy: 0.9679
# Epoch 17/50
# 178/178 [==============================] - 59s 333ms/step - loss: 0.0564 - accuracy: 0.9773 - val_loss: 0.1594 - val_accuracy: 0.9679
# Epoch 18/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.0641 - accuracy: 0.9751 - val_loss: 0.1855 - val_accuracy: 0.9679
# Epoch 19/50
# 178/178 [==============================] - 63s 353ms/step - loss: 0.0601 - accuracy: 0.9762 - val_loss: 0.1783 - val_accuracy: 0.9708
# Epoch 20/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.0557 - accuracy: 0.9757 - val_loss: 0.1804 - val_accuracy: 0.9720
# Epoch 21/50
# 178/178 [==============================] - 60s 337ms/step - loss: 0.0527 - accuracy: 0.9797 - val_loss: 0.1700 - val_accuracy: 0.9667
# Epoch 22/50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.0399 - accuracy: 0.9836 - val_loss: 0.2270 - val_accuracy: 0.9667
# Epoch 23/50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.0511 - accuracy: 0.9803 - val_loss: 0.1411 - val_accuracy: 0.9732
# Epoch 24/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.0460 - accuracy: 0.9811 - val_loss: 0.1896 - val_accuracy: 0.9712
# Epoch 25/50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.0417 - accuracy: 0.9836 - val_loss: 0.1571 - val_accuracy: 0.9749
# Epoch 26/50
# 178/178 [==============================] - 62s 351ms/step - loss: 0.0430 - accuracy: 0.9824 - val_loss: 0.1897 - val_accuracy: 0.9658
# Epoch 27/50
# 178/178 [==============================] - 59s 330ms/step - loss: 0.0537 - accuracy: 0.9799 - val_loss: 0.1641 - val_accuracy: 0.9716
# Epoch 28/50
# 178/178 [==============================] - 59s 333ms/step - loss: 0.0410 - accuracy: 0.9838 - val_loss: 0.2403 - val_accuracy: 0.9675
# Epoch 29/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.0466 - accuracy: 0.9815 - val_loss: 0.2061 - val_accuracy: 0.9704
# Epoch 30/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.0529 - accuracy: 0.9818 - val_loss: 0.2066 - val_accuracy: 0.9704
# Epoch 31/50
# 178/178 [==============================] - 62s 351ms/step - loss: 0.0454 - accuracy: 0.9818 - val_loss: 0.2200 - val_accuracy: 0.9699
# Epoch 32/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.0428 - accuracy: 0.9831 - val_loss: 0.1666 - val_accuracy: 0.9720
# Epoch 33/50
# 178/178 [==============================] - 60s 340ms/step - loss: 0.0398 - accuracy: 0.9827 - val_loss: 0.1555 - val_accuracy: 0.9753
# Epoch 34/50
# 178/178 [==============================] - 63s 351ms/step - loss: 0.0504 - accuracy: 0.9792 - val_loss: 0.2325 - val_accuracy: 0.9724
# Epoch 35/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.0407 - accuracy: 0.9818 - val_loss: 0.1763 - val_accuracy: 0.9757
# Epoch 36/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.0345 - accuracy: 0.9863 - val_loss: 0.2580 - val_accuracy: 0.9699
# Epoch 37/50
# 178/178 [==============================] - 59s 333ms/step - loss: 0.0387 - accuracy: 0.9845 - val_loss: 0.2013 - val_accuracy: 0.9745
# Epoch 38/50
# 178/178 [==============================] - 60s 337ms/step - loss: 0.0390 - accuracy: 0.9843 - val_loss: 0.1882 - val_accuracy: 0.9708
# Epoch 39/50
# 178/178 [==============================] - 62s 349ms/step - loss: 0.0369 - accuracy: 0.9854 - val_loss: 0.2454 - val_accuracy: 0.9667
# Epoch 40/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.0291 - accuracy: 0.9878 - val_loss: 0.1761 - val_accuracy: 0.9757
# Epoch 41/50
# 178/178 [==============================] - 63s 352ms/step - loss: 0.0319 - accuracy: 0.9859 - val_loss: 0.2331 - val_accuracy: 0.9737
# Epoch 42/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.0386 - accuracy: 0.9825 - val_loss: 0.2617 - val_accuracy: 0.9691
# Epoch 43/50
# 178/178 [==============================] - 59s 333ms/step - loss: 0.0334 - accuracy: 0.9852 - val_loss: 0.2052 - val_accuracy: 0.9716
# Epoch 44/50
# 178/178 [==============================] - 59s 334ms/step - loss: 0.0328 - accuracy: 0.9854 - val_loss: 0.1830 - val_accuracy: 0.9728
# Epoch 45/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.0274 - accuracy: 0.9889 - val_loss: 0.3142 - val_accuracy: 0.9687
# Epoch 46/50
# 178/178 [==============================] - 59s 334ms/step - loss: 0.0433 - accuracy: 0.9824 - val_loss: 0.2405 - val_accuracy: 0.9708
# Epoch 47/50
# 178/178 [==============================] - 59s 333ms/step - loss: 0.0356 - accuracy: 0.9841 - val_loss: 0.2286 - val_accuracy: 0.9728
# Epoch 48/50
# 178/178 [==============================] - 60s 334ms/step - loss: 0.0289 - accuracy: 0.9877 - val_loss: 0.2538 - val_accuracy: 0.9699
# Epoch 49/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.0311 - accuracy: 0.9866 - val_loss: 0.1984 - val_accuracy: 0.9786
# Epoch 50/50
# 178/178 [==============================] - 60s 334ms/step - loss: 0.0249 - accuracy: 0.9901 - val_loss: 0.2202 - val_accuracy: 0.9786
# 76/76 [==============================] - 18s 231ms/step - loss: 0.2202 - accuracy: 0.9786
# Accuracy on the Test Set = 97.86 %
# Model Saved!
# True :  [0 0 0 ... 4 4 4]
# 76/76 [==============================] - 18s 234ms/step
# Predicted :  [0 0 0 ... 4 2 4]
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_4 (Flatten)         (None, 25088)             0
#
#  dense_8 (Dense)             (None, 32)                802848
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_9 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 15,517,701
# Trainable params: 803,013
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/50
# 178/178 [==============================] - 62s 341ms/step - loss: 1.7585 - accuracy: 0.4527 - val_loss: 0.9213 - val_accuracy: 0.7023
# Epoch 2/50
# 178/178 [==============================] - 59s 333ms/step - loss: 0.9617 - accuracy: 0.6252 - val_loss: 0.5634 - val_accuracy: 0.8341
# Epoch 3/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.7760 - accuracy: 0.7062 - val_loss: 0.4478 - val_accuracy: 0.8543
# Epoch 4/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.6955 - accuracy: 0.7419 - val_loss: 0.3652 - val_accuracy: 0.8678
# Epoch 5/50
# 178/178 [==============================] - 60s 337ms/step - loss: 0.5948 - accuracy: 0.7761 - val_loss: 0.3339 - val_accuracy: 0.8703
# Epoch 6/50
# 178/178 [==============================] - 59s 333ms/step - loss: 0.5378 - accuracy: 0.7726 - val_loss: 0.3088 - val_accuracy: 0.9172
# Epoch 7/50
# 178/178 [==============================] - 61s 341ms/step - loss: 0.5050 - accuracy: 0.7883 - val_loss: 0.2423 - val_accuracy: 0.9333
# Epoch 8/50
# 178/178 [==============================] - 60s 337ms/step - loss: 0.4623 - accuracy: 0.7996 - val_loss: 0.2397 - val_accuracy: 0.9374
# Epoch 9/50
# 178/178 [==============================] - 60s 340ms/step - loss: 0.4400 - accuracy: 0.8154 - val_loss: 0.2053 - val_accuracy: 0.9461
# Epoch 10/50
# 178/178 [==============================] - 63s 356ms/step - loss: 0.4342 - accuracy: 0.8091 - val_loss: 0.2044 - val_accuracy: 0.9469
# Epoch 11/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.4208 - accuracy: 0.8149 - val_loss: 0.1967 - val_accuracy: 0.9494
# Epoch 12/50
# 178/178 [==============================] - 60s 337ms/step - loss: 0.4126 - accuracy: 0.8170 - val_loss: 0.2138 - val_accuracy: 0.9477
# Epoch 13/50
# 178/178 [==============================] - 63s 354ms/step - loss: 0.4175 - accuracy: 0.8161 - val_loss: 0.1790 - val_accuracy: 0.9527
# Epoch 14/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.3938 - accuracy: 0.8301 - val_loss: 0.1894 - val_accuracy: 0.9420
# Epoch 15/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.3903 - accuracy: 0.8271 - val_loss: 0.1933 - val_accuracy: 0.9448
# Epoch 16/50
# 178/178 [==============================] - 59s 329ms/step - loss: 0.3985 - accuracy: 0.8257 - val_loss: 0.1690 - val_accuracy: 0.9498
# Epoch 17/50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.3900 - accuracy: 0.8352 - val_loss: 0.1529 - val_accuracy: 0.9576
# Epoch 18/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.3884 - accuracy: 0.8355 - val_loss: 0.1677 - val_accuracy: 0.9522
# Epoch 19/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.3759 - accuracy: 0.8377 - val_loss: 0.1572 - val_accuracy: 0.9588
# Epoch 20/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.3771 - accuracy: 0.8389 - val_loss: 0.1548 - val_accuracy: 0.9584
# Epoch 21/50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.3690 - accuracy: 0.8403 - val_loss: 0.1777 - val_accuracy: 0.9597
# Epoch 22/50
# 178/178 [==============================] - 62s 351ms/step - loss: 0.3687 - accuracy: 0.8449 - val_loss: 0.1860 - val_accuracy: 0.9436
# Epoch 23/50

# %%
batch_size = [32]
dropout = [0.5]

# %%
for i in range(1):
  for j in range(1):
    curModel = initiateModel(noOfClasses,dropout[j])
    modelSummary(curModel)
    curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
    curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=batch_size[i])
    plotOutput(curHistory, className, gEpochs)
    evalModel(curModel)
    saveModel(curModel, className)
    callPlot(curModel, className, class_names)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 32)                802848
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 15,517,701
# Trainable params: 803,013
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Epoch 1/50
# 178/178 [==============================] - 3935s 22s/step - loss: 1.6832 - accuracy: 0.5189 - val_loss: 0.5301 - val_accuracy: 0.7913
# Epoch 2/50
# 178/178 [==============================] - 61s 340ms/step - loss: 0.7708 - accuracy: 0.6924 - val_loss: 0.4330 - val_accuracy: 0.8510
# Epoch 3/50
# 178/178 [==============================] - 60s 339ms/step - loss: 0.5985 - accuracy: 0.7701 - val_loss: 0.2710 - val_accuracy: 0.9230
# Epoch 4/50
# 178/178 [==============================] - 60s 338ms/step - loss: 0.5108 - accuracy: 0.8029 - val_loss: 0.2134 - val_accuracy: 0.9242
# Epoch 5/50
# 178/178 [==============================] - 60s 337ms/step - loss: 0.4330 - accuracy: 0.8445 - val_loss: 0.2042 - val_accuracy: 0.9387
# Epoch 6/50
# 178/178 [==============================] - 60s 338ms/step - loss: 0.3793 - accuracy: 0.8634 - val_loss: 0.1624 - val_accuracy: 0.9477
# Epoch 7/50
# 178/178 [==============================] - 61s 343ms/step - loss: 0.3444 - accuracy: 0.8805 - val_loss: 0.1794 - val_accuracy: 0.9543
# Epoch 8/50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.3208 - accuracy: 0.8886 - val_loss: 0.1402 - val_accuracy: 0.9580
# Epoch 9/50
# 178/178 [==============================] - 60s 337ms/step - loss: 0.2968 - accuracy: 0.8981 - val_loss: 0.1648 - val_accuracy: 0.9584
# Epoch 10/50
# 178/178 [==============================] - 60s 338ms/step - loss: 0.2683 - accuracy: 0.9068 - val_loss: 0.1505 - val_accuracy: 0.9634
# Epoch 11/50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.2797 - accuracy: 0.9069 - val_loss: 0.1266 - val_accuracy: 0.9625
# Epoch 12/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.2547 - accuracy: 0.9138 - val_loss: 0.1528 - val_accuracy: 0.9629
# Epoch 13/50
# 178/178 [==============================] - 63s 353ms/step - loss: 0.2447 - accuracy: 0.9142 - val_loss: 0.1884 - val_accuracy: 0.9605
# Epoch 14/50
# 178/178 [==============================] - 60s 338ms/step - loss: 0.2453 - accuracy: 0.9145 - val_loss: 0.1448 - val_accuracy: 0.9621
# Epoch 15/50
# 178/178 [==============================] - 61s 343ms/step - loss: 0.2315 - accuracy: 0.9149 - val_loss: 0.1604 - val_accuracy: 0.9625
# Epoch 16/50
# 178/178 [==============================] - 59s 333ms/step - loss: 0.2368 - accuracy: 0.9214 - val_loss: 0.1276 - val_accuracy: 0.9662
# Epoch 17/50
# 178/178 [==============================] - 59s 333ms/step - loss: 0.2258 - accuracy: 0.9261 - val_loss: 0.1305 - val_accuracy: 0.9621
# Epoch 18/50
# 178/178 [==============================] - 60s 339ms/step - loss: 0.2100 - accuracy: 0.9300 - val_loss: 0.1215 - val_accuracy: 0.9671
# Epoch 19/50
# 178/178 [==============================] - 59s 333ms/step - loss: 0.1990 - accuracy: 0.9332 - val_loss: 0.1261 - val_accuracy: 0.9650
# Epoch 20/50
# 178/178 [==============================] - 59s 334ms/step - loss: 0.2254 - accuracy: 0.9226 - val_loss: 0.1234 - val_accuracy: 0.9634
# Epoch 21/50
# 178/178 [==============================] - 60s 340ms/step - loss: 0.2130 - accuracy: 0.9286 - val_loss: 0.1353 - val_accuracy: 0.9671
# Epoch 22/50
# 178/178 [==============================] - 60s 338ms/step - loss: 0.1957 - accuracy: 0.9357 - val_loss: 0.1205 - val_accuracy: 0.9671
# Epoch 23/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.1958 - accuracy: 0.9372 - val_loss: 0.1396 - val_accuracy: 0.9667
# Epoch 24/50
# 178/178 [==============================] - 60s 338ms/step - loss: 0.1975 - accuracy: 0.9295 - val_loss: 0.1926 - val_accuracy: 0.9683
# Epoch 25/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.2041 - accuracy: 0.9263 - val_loss: 0.1282 - val_accuracy: 0.9724
# Epoch 26/50
# 178/178 [==============================] - 63s 355ms/step - loss: 0.1981 - accuracy: 0.9314 - val_loss: 0.1541 - val_accuracy: 0.9704
# Epoch 27/50
# 178/178 [==============================] - 60s 334ms/step - loss: 0.1892 - accuracy: 0.9346 - val_loss: 0.1248 - val_accuracy: 0.9728
# Epoch 28/50
# 178/178 [==============================] - 63s 353ms/step - loss: 0.1977 - accuracy: 0.9300 - val_loss: 0.1182 - val_accuracy: 0.9737
# Epoch 29/50
# 178/178 [==============================] - 59s 333ms/step - loss: 0.1912 - accuracy: 0.9346 - val_loss: 0.2269 - val_accuracy: 0.9638
# Epoch 30/50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.1810 - accuracy: 0.9362 - val_loss: 0.1143 - val_accuracy: 0.9724
# Epoch 31/50
# 178/178 [==============================] - 60s 339ms/step - loss: 0.1724 - accuracy: 0.9339 - val_loss: 0.1678 - val_accuracy: 0.9716
# Epoch 32/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.1852 - accuracy: 0.9325 - val_loss: 0.1759 - val_accuracy: 0.9712
# Epoch 33/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.1698 - accuracy: 0.9402 - val_loss: 0.1746 - val_accuracy: 0.9720
# Epoch 34/50
# 178/178 [==============================] - 63s 352ms/step - loss: 0.1674 - accuracy: 0.9409 - val_loss: 0.1577 - val_accuracy: 0.9699
# Epoch 35/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.1681 - accuracy: 0.9388 - val_loss: 0.2513 - val_accuracy: 0.9683
# Epoch 36/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.1702 - accuracy: 0.9357 - val_loss: 0.1508 - val_accuracy: 0.9704
# Epoch 37/50
# 178/178 [==============================] - 60s 339ms/step - loss: 0.1793 - accuracy: 0.9339 - val_loss: 0.1978 - val_accuracy: 0.9716
# Epoch 38/50
# 178/178 [==============================] - 59s 333ms/step - loss: 0.1576 - accuracy: 0.9397 - val_loss: 0.1658 - val_accuracy: 0.9687
# Epoch 39/50
# 178/178 [==============================] - 63s 354ms/step - loss: 0.1641 - accuracy: 0.9408 - val_loss: 0.1782 - val_accuracy: 0.9720
# Epoch 40/50
# 178/178 [==============================] - 59s 330ms/step - loss: 0.1657 - accuracy: 0.9390 - val_loss: 0.1851 - val_accuracy: 0.9691
# Epoch 41/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.1614 - accuracy: 0.9408 - val_loss: 0.1642 - val_accuracy: 0.9720
# Epoch 42/50
# 178/178 [==============================] - 63s 352ms/step - loss: 0.1643 - accuracy: 0.9420 - val_loss: 0.1805 - val_accuracy: 0.9708
# Epoch 43/50
# 178/178 [==============================] - 59s 333ms/step - loss: 0.1488 - accuracy: 0.9450 - val_loss: 0.1989 - val_accuracy: 0.9687
# Epoch 44/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.1549 - accuracy: 0.9448 - val_loss: 0.1840 - val_accuracy: 0.9683
# Epoch 45/50
# 178/178 [==============================] - 60s 337ms/step - loss: 0.1398 - accuracy: 0.9461 - val_loss: 0.2179 - val_accuracy: 0.9708
# Epoch 46/50
# 178/178 [==============================] - 59s 333ms/step - loss: 0.1672 - accuracy: 0.9436 - val_loss: 0.1709 - val_accuracy: 0.9724
# Epoch 47/50
# 178/178 [==============================] - 59s 334ms/step - loss: 0.1493 - accuracy: 0.9417 - val_loss: 0.2213 - val_accuracy: 0.9691
# Epoch 48/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.1494 - accuracy: 0.9471 - val_loss: 0.2332 - val_accuracy: 0.9683
# Epoch 49/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.1659 - accuracy: 0.9378 - val_loss: 0.2566 - val_accuracy: 0.9712
# Epoch 50/50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.1520 - accuracy: 0.9424 - val_loss: 0.1988 - val_accuracy: 0.9724
# 76/76 [==============================] - 18s 234ms/step - loss: 0.1988 - accuracy: 0.9724
# Accuracy on the Test Set = 97.24 %
# Model Saved!
# True :  [0 0 0 ... 4 4 4]
# 76/76 [==============================] - 18s 236ms/step
# Predicted :  [0 1 0 ... 4 4 4]
