# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from keras.layers import Input, Lambda, Dense, Flatten,Dropout
from keras.models import Model
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import layers
from matplotlib.pyplot import figure
plt.style.use('ggplot')

# %%
def initiateGenerator(path):
    base_path = path
    print("\nTotal : ", end=" ")
    train_dataset = tf.keras.preprocessing.image_dataset_from_directory(batch_size=32, directory=base_path)

    train_datagen = ImageDataGenerator(validation_split=0.3)

    print("\nFor Training : ", end=" ")
    train_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical', subset='training')

    print("\nFor Val : ", end=" ")
    validation_generator = train_datagen.flow_from_directory(
        base_path,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',
        subset='validation', shuffle=False)

    class_names = train_dataset.class_names
    noOfClasses = len(class_names)
    print("\nNo of Classes : ", noOfClasses)
    print("Classes : ", class_names)

    plt.figure(figsize=(10, 10))
    for images, labels in train_dataset.take(1):
        for i in range(noOfClasses):
            ax = plt.subplot(4, 4, i + 1)
            plt.imshow(images[i].numpy().astype("uint8"))
            plt.title(class_names[labels[i]])
            plt.axis("off")

    for image_batch, labels_batch in train_dataset:
        print("Image Shape : ",image_batch.shape)
        break
        
    return noOfClasses,class_names, train_generator, validation_generator

# %%
def initiateNormalize():
    AUTOTUNE = tf.data.AUTOTUNE

    train_ds = train_generator.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
    val_ds = val_generator.cache().prefetch(buffer_size=AUTOTUNE)
    normalization_layer = layers.Rescaling(1./255)

    normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
    image_batch, labels_batch = next(iter(normalized_ds))
    first_image = image_batch[0]
    print(np.min(first_image), np.max(first_image))

# %%
def initiateModel(noOfClasses,dropout):
    modelInput = tf.keras.applications.VGG19(
        input_shape=IMAGE_SIZE + [3],
        include_top=False,
        weights="imagenet"
    )
    
    for layer in modelInput.layers:
        layer.trainable = False
    
    x = Flatten()(modelInput.output)
    x=Dense(32,activation='relu')(x)
    x=Dropout(dropout)(x)
    prediction = Dense(noOfClasses, activation='softmax')(x)

    model = Model(inputs=modelInput.input, outputs=prediction)
    return model

def modelSummary(model):
    model.summary()

# %%
def initiateParams(className, model, lr):
    opt = tf.keras.optimizers.Adam(learning_rate=lr)

    model.compile(optimizer=opt,
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, verbose=1, min_lr=1e-3)
    checkpoint = ModelCheckpoint(className + 'VGG16.h5', verbose=1, save_best_only=True)
    
    return model, annealer, checkpoint

# %%
def modelFit(model, annealer, checkpoint, epochs=20, batchSize = 16):

    history = model.fit(
      train_generator,
      validation_data=validation_generator,
      epochs=epochs,
      batch_size=batchSize,
      #callbacks=[annealer, checkpoint],
      steps_per_epoch=len(train_generator),
      validation_steps=len(validation_generator)
    )
    
    return history

# %%
def plotOutput(history, className, epochs):
    figure(figsize=(10, 7), dpi=80)
    # plt.plot([1, 0], [0, 1], 'k--')
    plt.plot(history.history['accuracy'],label='Training_accuracy')
    plt.plot(history.history['val_accuracy'],label='Validation_accuracy')
    plt.plot(history.history['loss'],label='Training_loss')
    plt.plot(history.history['val_loss'],label='Validation_loss')
    plt.legend()
    plt.title('Training Accuracy vs Validation Accuracy & Training Loss vs Validation Loss')
    plt.xlabel('No.of epochs')
    plt.ylabel('Accuracy')
    plt.xlabel('Np.of epochs')
    plt.ylabel('Loss')
    plt.show()

# %%
def evalModel(model):
    evl = model.evaluate(validation_generator)
    acc = evl[1]*100
    msg=f'Accuracy on the Test Set = {acc:5.2f} %'
    print(msg)
    
def saveModel(model, className):
    model.save(className + " - VGG16.h5")
    print("Model Saved!")

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(15, 15))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    plt.savefig(title + '.png')

# %%
def callPlot(model, className, classes):
    y_true = validation_generator.classes
    print("True : ", (y_true))

    y_pred = model.predict(validation_generator)
    y_pred = np.argmax(y_pred, axis=1)
    print("Predicted : ", (y_pred))

    conf_mat = confusion_matrix(y_true, y_pred)

    plot_confusion_matrix(cm           = conf_mat,
                          normalize    = False,
                          target_names = classes,
                          title        = className + "Confusion Matrix")

# %%
mpath = r'/content/drive/MyDrive/Lung and Colon'
classPaths = os.listdir(mpath)

IMAGE_SIZE = [224, 224]
img_height = 224
img_width = 224
noOfClasses = 0
gEpochs = 50
lr = 0.0001

for i in classPaths:
    print(i)
# Out:
# Dataset
# code

# %%
className = 'Dataset'
cpath = os.path.join(mpath, 'Dataset')
noOfClasses, class_names, train_generator, validation_generator = initiateGenerator(cpath)
# Out:
# Total :  Found 8102 files belonging to 5 classes.
#
# For Training :  Found 5673 images belonging to 5 classes.
#
# For Val :  Found 2429 images belonging to 5 classes.
#
# No of Classes :  5
# Classes :  ['colon_aca', 'colon_bnt', 'lung_aca', 'lung_bnt', 'lung_scc']
# Image Shape :  (32, 256, 256, 3)

# %%
batch_size = [16,32]
dropout = [0.3,0.5]

# %%
for i in range(2):
  for j in range(2):
    curModel = initiateModel(noOfClasses,dropout[j])
    modelSummary(curModel)
    curModel, annealer, checkpoint = initiateParams(className, curModel, lr)
    curHistory = modelFit(curModel, annealer, checkpoint, epochs=gEpochs, batchSize=batch_size[i])
    plotOutput(curHistory, className, gEpochs)
    evalModel(curModel)
    saveModel(curModel, className)
    callPlot(curModel, className, class_names)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 32)                802848
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 20,827,397
# Trainable params: 803,013
# Non-trainable params: 20,024,384
# _________________________________________________________________
# Epoch 1/50
# 178/178 [==============================] - 1435s 8s/step - loss: 1.3270 - accuracy: 0.6355 - val_loss: 0.4176 - val_accuracy: 0.8526
# Epoch 2/50
# 178/178 [==============================] - 61s 340ms/step - loss: 0.4760 - accuracy: 0.8195 - val_loss: 0.2584 - val_accuracy: 0.9037
# Epoch 3/50
# 178/178 [==============================] - 60s 339ms/step - loss: 0.3076 - accuracy: 0.8697 - val_loss: 0.2800 - val_accuracy: 0.9078
# Epoch 4/50
# 178/178 [==============================] - 60s 338ms/step - loss: 0.2271 - accuracy: 0.9066 - val_loss: 0.2268 - val_accuracy: 0.9362
# Epoch 5/50
# 178/178 [==============================] - 62s 350ms/step - loss: 0.2079 - accuracy: 0.9147 - val_loss: 0.1762 - val_accuracy: 0.9452
# Epoch 6/50
# 178/178 [==============================] - 59s 329ms/step - loss: 0.1638 - accuracy: 0.9327 - val_loss: 0.1821 - val_accuracy: 0.9473
# Epoch 7/50
# 178/178 [==============================] - 59s 330ms/step - loss: 0.1568 - accuracy: 0.9346 - val_loss: 0.2303 - val_accuracy: 0.9387
# Epoch 8/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.1374 - accuracy: 0.9415 - val_loss: 0.1836 - val_accuracy: 0.9531
# Epoch 9/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.1265 - accuracy: 0.9476 - val_loss: 0.2117 - val_accuracy: 0.9485
# Epoch 10/50
# 178/178 [==============================] - 59s 334ms/step - loss: 0.1185 - accuracy: 0.9494 - val_loss: 0.1703 - val_accuracy: 0.9568
# Epoch 11/50
# 178/178 [==============================] - 60s 337ms/step - loss: 0.1092 - accuracy: 0.9586 - val_loss: 0.1989 - val_accuracy: 0.9465
# Epoch 12/50
# 178/178 [==============================] - 60s 337ms/step - loss: 0.0866 - accuracy: 0.9672 - val_loss: 0.2039 - val_accuracy: 0.9543
# Epoch 13/50
# 178/178 [==============================] - 60s 336ms/step - loss: 0.1027 - accuracy: 0.9610 - val_loss: 0.2271 - val_accuracy: 0.9510
# Epoch 14/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.1059 - accuracy: 0.9584 - val_loss: 0.1521 - val_accuracy: 0.9592
# Epoch 15/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.0779 - accuracy: 0.9662 - val_loss: 0.1879 - val_accuracy: 0.9576
# Epoch 16/50
# 178/178 [==============================] - 59s 330ms/step - loss: 0.0898 - accuracy: 0.9704 - val_loss: 0.2312 - val_accuracy: 0.9531
# Epoch 17/50
# 178/178 [==============================] - 62s 349ms/step - loss: 0.0766 - accuracy: 0.9686 - val_loss: 0.1944 - val_accuracy: 0.9588
# Epoch 18/50
# 178/178 [==============================] - 60s 337ms/step - loss: 0.0927 - accuracy: 0.9595 - val_loss: 0.1807 - val_accuracy: 0.9609
# Epoch 19/50
# 178/178 [==============================] - 59s 329ms/step - loss: 0.0718 - accuracy: 0.9690 - val_loss: 0.1623 - val_accuracy: 0.9576
# Epoch 20/50
# 178/178 [==============================] - 59s 329ms/step - loss: 0.0736 - accuracy: 0.9692 - val_loss: 0.1967 - val_accuracy: 0.9588
# Epoch 21/50
# 178/178 [==============================] - 59s 334ms/step - loss: 0.0656 - accuracy: 0.9723 - val_loss: 0.1828 - val_accuracy: 0.9572
# Epoch 22/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.0705 - accuracy: 0.9713 - val_loss: 0.1738 - val_accuracy: 0.9613
# Epoch 23/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.0592 - accuracy: 0.9743 - val_loss: 0.1501 - val_accuracy: 0.9634
# Epoch 24/50
# 178/178 [==============================] - 62s 348ms/step - loss: 0.0639 - accuracy: 0.9723 - val_loss: 0.1664 - val_accuracy: 0.9580
# Epoch 25/50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.0622 - accuracy: 0.9706 - val_loss: 0.1538 - val_accuracy: 0.9609
# Epoch 26/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.0674 - accuracy: 0.9707 - val_loss: 0.1715 - val_accuracy: 0.9658
# Epoch 27/50
# 178/178 [==============================] - 62s 348ms/step - loss: 0.0573 - accuracy: 0.9750 - val_loss: 0.1805 - val_accuracy: 0.9601
# Epoch 28/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.0629 - accuracy: 0.9755 - val_loss: 0.1847 - val_accuracy: 0.9547
# Epoch 29/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.0587 - accuracy: 0.9748 - val_loss: 0.1592 - val_accuracy: 0.9625
# Epoch 30/50
# 178/178 [==============================] - 59s 330ms/step - loss: 0.0551 - accuracy: 0.9771 - val_loss: 0.2090 - val_accuracy: 0.9559
# Epoch 31/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.0656 - accuracy: 0.9729 - val_loss: 0.1916 - val_accuracy: 0.9588
# Epoch 32/50
# 178/178 [==============================] - 60s 335ms/step - loss: 0.0511 - accuracy: 0.9767 - val_loss: 0.1867 - val_accuracy: 0.9650
# Epoch 33/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.0540 - accuracy: 0.9764 - val_loss: 0.2038 - val_accuracy: 0.9629
# Epoch 34/50
# 178/178 [==============================] - 62s 346ms/step - loss: 0.0509 - accuracy: 0.9811 - val_loss: 0.2286 - val_accuracy: 0.9650
# Epoch 35/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.0437 - accuracy: 0.9803 - val_loss: 0.1879 - val_accuracy: 0.9629
# Epoch 36/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.0497 - accuracy: 0.9776 - val_loss: 0.2115 - val_accuracy: 0.9597
# Epoch 37/50
# 178/178 [==============================] - 62s 347ms/step - loss: 0.0516 - accuracy: 0.9801 - val_loss: 0.1701 - val_accuracy: 0.9605
# Epoch 38/50
# 178/178 [==============================] - 58s 325ms/step - loss: 0.0481 - accuracy: 0.9787 - val_loss: 0.2005 - val_accuracy: 0.9662
# Epoch 39/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.0521 - accuracy: 0.9804 - val_loss: 0.2268 - val_accuracy: 0.9658
# Epoch 40/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.0423 - accuracy: 0.9833 - val_loss: 0.1969 - val_accuracy: 0.9642
# Epoch 41/50
# 178/178 [==============================] - 58s 325ms/step - loss: 0.0427 - accuracy: 0.9818 - val_loss: 0.1806 - val_accuracy: 0.9683
# Epoch 42/50
# 178/178 [==============================] - 59s 329ms/step - loss: 0.0468 - accuracy: 0.9806 - val_loss: 0.2082 - val_accuracy: 0.9646
# Epoch 43/50
# 178/178 [==============================] - 62s 351ms/step - loss: 0.0565 - accuracy: 0.9790 - val_loss: 0.2024 - val_accuracy: 0.9667
# Epoch 44/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.0579 - accuracy: 0.9780 - val_loss: 0.1915 - val_accuracy: 0.9646
# Epoch 45/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.0311 - accuracy: 0.9866 - val_loss: 0.2325 - val_accuracy: 0.9658
# Epoch 46/50
# 178/178 [==============================] - 60s 338ms/step - loss: 0.0458 - accuracy: 0.9827 - val_loss: 0.1789 - val_accuracy: 0.9662
# Epoch 47/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.0422 - accuracy: 0.9827 - val_loss: 0.2379 - val_accuracy: 0.9634
# Epoch 48/50
# 178/178 [==============================] - 59s 330ms/step - loss: 0.0392 - accuracy: 0.9841 - val_loss: 0.2124 - val_accuracy: 0.9642
# Epoch 49/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.0383 - accuracy: 0.9836 - val_loss: 0.1931 - val_accuracy: 0.9646
# Epoch 50/50
# 178/178 [==============================] - 59s 328ms/step - loss: 0.0313 - accuracy: 0.9843 - val_loss: 0.1819 - val_accuracy: 0.9662
# 76/76 [==============================] - 18s 230ms/step - loss: 0.1819 - accuracy: 0.9662
# Accuracy on the Test Set = 96.62 %
# Model Saved!
# True :  [0 0 0 ... 4 4 4]
# 76/76 [==============================] - 19s 250ms/step
# Predicted :  [0 1 0 ... 4 4 4]
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 32)                802848
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 20,827,397
# Trainable params: 803,013
# Non-trainable params: 20,024,384
# _________________________________________________________________
# Epoch 1/50
# 178/178 [==============================] - 60s 330ms/step - loss: 1.6371 - accuracy: 0.5260 - val_loss: 0.5682 - val_accuracy: 0.8139
# Epoch 2/50
# 178/178 [==============================] - 63s 355ms/step - loss: 0.8010 - accuracy: 0.7137 - val_loss: 0.4618 - val_accuracy: 0.8810
# Epoch 3/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.5918 - accuracy: 0.7897 - val_loss: 0.2771 - val_accuracy: 0.9135
# Epoch 4/50
# 178/178 [==============================] - 59s 330ms/step - loss: 0.5134 - accuracy: 0.8163 - val_loss: 0.3551 - val_accuracy: 0.8958
# Epoch 5/50
# 178/178 [==============================] - 62s 347ms/step - loss: 0.4287 - accuracy: 0.8336 - val_loss: 0.2383 - val_accuracy: 0.9337
# Epoch 6/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.3910 - accuracy: 0.8489 - val_loss: 0.2177 - val_accuracy: 0.9415
# Epoch 7/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.3335 - accuracy: 0.8673 - val_loss: 0.2095 - val_accuracy: 0.9502
# Epoch 8/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.2933 - accuracy: 0.8861 - val_loss: 0.2401 - val_accuracy: 0.9494
# Epoch 9/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.2711 - accuracy: 0.8898 - val_loss: 0.2401 - val_accuracy: 0.9510
# Epoch 10/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.2755 - accuracy: 0.8956 - val_loss: 0.1703 - val_accuracy: 0.9494
# Epoch 11/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.2323 - accuracy: 0.9039 - val_loss: 0.1634 - val_accuracy: 0.9543
# Epoch 12/50
# 178/178 [==============================] - 59s 334ms/step - loss: 0.2210 - accuracy: 0.9073 - val_loss: 0.1849 - val_accuracy: 0.9613
# Epoch 13/50
# 178/178 [==============================] - 58s 325ms/step - loss: 0.2110 - accuracy: 0.9120 - val_loss: 0.2363 - val_accuracy: 0.9568
# Epoch 14/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.2005 - accuracy: 0.9145 - val_loss: 0.2151 - val_accuracy: 0.9617
# Epoch 15/50
# 178/178 [==============================] - 62s 348ms/step - loss: 0.2032 - accuracy: 0.9133 - val_loss: 0.2319 - val_accuracy: 0.9559
# Epoch 16/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.1907 - accuracy: 0.9194 - val_loss: 0.1757 - val_accuracy: 0.9629
# Epoch 17/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.1942 - accuracy: 0.9198 - val_loss: 0.2058 - val_accuracy: 0.9609
# Epoch 18/50
# 178/178 [==============================] - 62s 347ms/step - loss: 0.1814 - accuracy: 0.9237 - val_loss: 0.1481 - val_accuracy: 0.9609
# Epoch 19/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.1721 - accuracy: 0.9249 - val_loss: 0.2361 - val_accuracy: 0.9588
# Epoch 20/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.1800 - accuracy: 0.9226 - val_loss: 0.1834 - val_accuracy: 0.9576
# Epoch 21/50
# 178/178 [==============================] - 62s 346ms/step - loss: 0.1708 - accuracy: 0.9249 - val_loss: 0.1836 - val_accuracy: 0.9642
# Epoch 22/50
# 178/178 [==============================] - 63s 353ms/step - loss: 0.1500 - accuracy: 0.9353 - val_loss: 0.2196 - val_accuracy: 0.9588
# Epoch 23/50
# 178/178 [==============================] - 59s 329ms/step - loss: 0.1648 - accuracy: 0.9261 - val_loss: 0.2261 - val_accuracy: 0.9592
# Epoch 24/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.1526 - accuracy: 0.9288 - val_loss: 0.2044 - val_accuracy: 0.9588
# Epoch 25/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.1455 - accuracy: 0.9305 - val_loss: 0.2520 - val_accuracy: 0.9625
# Epoch 26/50
# 178/178 [==============================] - 62s 346ms/step - loss: 0.1477 - accuracy: 0.9325 - val_loss: 0.2194 - val_accuracy: 0.9613
# Epoch 27/50
# 178/178 [==============================] - 59s 328ms/step - loss: 0.1594 - accuracy: 0.9425 - val_loss: 0.1974 - val_accuracy: 0.9609
# Epoch 28/50
# 178/178 [==============================] - 59s 330ms/step - loss: 0.1594 - accuracy: 0.9441 - val_loss: 0.2745 - val_accuracy: 0.9609
# Epoch 29/50
# 178/178 [==============================] - 59s 329ms/step - loss: 0.1461 - accuracy: 0.9441 - val_loss: 0.2380 - val_accuracy: 0.9650
# Epoch 30/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.1562 - accuracy: 0.9434 - val_loss: 0.1894 - val_accuracy: 0.9638
# Epoch 31/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.1409 - accuracy: 0.9462 - val_loss: 0.2172 - val_accuracy: 0.9564
# Epoch 32/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.1414 - accuracy: 0.9499 - val_loss: 0.2250 - val_accuracy: 0.9625
# Epoch 33/50
# 178/178 [==============================] - 59s 330ms/step - loss: 0.1292 - accuracy: 0.9499 - val_loss: 0.2195 - val_accuracy: 0.9617
# Epoch 34/50
# 178/178 [==============================] - 57s 323ms/step - loss: 0.1359 - accuracy: 0.9512 - val_loss: 0.2151 - val_accuracy: 0.9597
# Epoch 35/50
# 178/178 [==============================] - 59s 329ms/step - loss: 0.1433 - accuracy: 0.9476 - val_loss: 0.2152 - val_accuracy: 0.9675
# Epoch 36/50
# 178/178 [==============================] - 62s 346ms/step - loss: 0.1210 - accuracy: 0.9596 - val_loss: 0.2319 - val_accuracy: 0.9605
# Epoch 37/50
# 178/178 [==============================] - 58s 325ms/step - loss: 0.1405 - accuracy: 0.9478 - val_loss: 0.2228 - val_accuracy: 0.9658
# Epoch 38/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.1319 - accuracy: 0.9443 - val_loss: 0.1957 - val_accuracy: 0.9629
# Epoch 39/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.1367 - accuracy: 0.9512 - val_loss: 0.2275 - val_accuracy: 0.9592
# Epoch 40/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.1339 - accuracy: 0.9519 - val_loss: 0.2610 - val_accuracy: 0.9634
# Epoch 41/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.1247 - accuracy: 0.9538 - val_loss: 0.2315 - val_accuracy: 0.9609
# Epoch 42/50
# 178/178 [==============================] - 58s 323ms/step - loss: 0.1186 - accuracy: 0.9524 - val_loss: 0.2437 - val_accuracy: 0.9625
# Epoch 43/50
# 178/178 [==============================] - 59s 330ms/step - loss: 0.1263 - accuracy: 0.9554 - val_loss: 0.1953 - val_accuracy: 0.9605
# Epoch 44/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.1166 - accuracy: 0.9584 - val_loss: 0.2539 - val_accuracy: 0.9617
# Epoch 45/50
# 178/178 [==============================] - 61s 343ms/step - loss: 0.1212 - accuracy: 0.9582 - val_loss: 0.2757 - val_accuracy: 0.9642
# Epoch 46/50
# 178/178 [==============================] - 57s 323ms/step - loss: 0.1176 - accuracy: 0.9566 - val_loss: 0.2112 - val_accuracy: 0.9617
# Epoch 47/50
# 178/178 [==============================] - 62s 346ms/step - loss: 0.1318 - accuracy: 0.9563 - val_loss: 0.1874 - val_accuracy: 0.9650
# Epoch 48/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.1328 - accuracy: 0.9524 - val_loss: 0.1883 - val_accuracy: 0.9683
# Epoch 49/50
# 178/178 [==============================] - 58s 325ms/step - loss: 0.1466 - accuracy: 0.9461 - val_loss: 0.1788 - val_accuracy: 0.9679
# Epoch 50/50
# 178/178 [==============================] - 58s 323ms/step - loss: 0.1307 - accuracy: 0.9510 - val_loss: 0.2432 - val_accuracy: 0.9629
# 76/76 [==============================] - 18s 235ms/step - loss: 0.2432 - accuracy: 0.9629
# Accuracy on the Test Set = 96.29 %
# Model Saved!
# True :  [0 0 0 ... 4 4 4]
# 76/76 [==============================] - 18s 229ms/step
# Predicted :  [0 0 0 ... 4 2 4]
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_2 (Flatten)         (None, 25088)             0
#
#  dense_4 (Dense)             (None, 32)                802848
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 20,827,397
# Trainable params: 803,013
# Non-trainable params: 20,024,384
# _________________________________________________________________
# Epoch 1/50
# 178/178 [==============================] - 60s 329ms/step - loss: 1.3476 - accuracy: 0.6242 - val_loss: 0.4388 - val_accuracy: 0.8164
# Epoch 2/50
# 178/178 [==============================] - 58s 325ms/step - loss: 0.4862 - accuracy: 0.8109 - val_loss: 0.2675 - val_accuracy: 0.8934
# Epoch 3/50
# 178/178 [==============================] - 59s 333ms/step - loss: 0.3206 - accuracy: 0.8837 - val_loss: 0.2249 - val_accuracy: 0.9263
# Epoch 4/50
# 178/178 [==============================] - 57s 320ms/step - loss: 0.2725 - accuracy: 0.8995 - val_loss: 0.2100 - val_accuracy: 0.9337
# Epoch 5/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.2145 - accuracy: 0.9189 - val_loss: 0.1973 - val_accuracy: 0.9424
# Epoch 6/50
# 178/178 [==============================] - 58s 325ms/step - loss: 0.1817 - accuracy: 0.9302 - val_loss: 0.1958 - val_accuracy: 0.9485
# Epoch 7/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.1815 - accuracy: 0.9362 - val_loss: 0.1621 - val_accuracy: 0.9531
# Epoch 8/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.1391 - accuracy: 0.9487 - val_loss: 0.1989 - val_accuracy: 0.9502
# Epoch 9/50
# 178/178 [==============================] - 62s 350ms/step - loss: 0.1382 - accuracy: 0.9531 - val_loss: 0.1728 - val_accuracy: 0.9514
# Epoch 10/50
# 178/178 [==============================] - 58s 325ms/step - loss: 0.1227 - accuracy: 0.9512 - val_loss: 0.1852 - val_accuracy: 0.9498
# Epoch 11/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.1085 - accuracy: 0.9591 - val_loss: 0.1829 - val_accuracy: 0.9527
# Epoch 12/50
# 178/178 [==============================] - 57s 320ms/step - loss: 0.1048 - accuracy: 0.9588 - val_loss: 0.1770 - val_accuracy: 0.9535
# Epoch 13/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.1038 - accuracy: 0.9566 - val_loss: 0.2424 - val_accuracy: 0.9494
# Epoch 14/50
# 178/178 [==============================] - 59s 330ms/step - loss: 0.0876 - accuracy: 0.9656 - val_loss: 0.2046 - val_accuracy: 0.9555
# Epoch 15/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.0896 - accuracy: 0.9681 - val_loss: 0.1854 - val_accuracy: 0.9576
# Epoch 16/50
# 178/178 [==============================] - 58s 323ms/step - loss: 0.0889 - accuracy: 0.9662 - val_loss: 0.1673 - val_accuracy: 0.9568
# Epoch 17/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.0902 - accuracy: 0.9676 - val_loss: 0.1723 - val_accuracy: 0.9580
# Epoch 18/50
# 178/178 [==============================] - 58s 323ms/step - loss: 0.0822 - accuracy: 0.9709 - val_loss: 0.1923 - val_accuracy: 0.9617
# Epoch 19/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.0768 - accuracy: 0.9716 - val_loss: 0.1690 - val_accuracy: 0.9642
# Epoch 20/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.0719 - accuracy: 0.9744 - val_loss: 0.1882 - val_accuracy: 0.9634
# Epoch 21/50
# 178/178 [==============================] - 62s 345ms/step - loss: 0.0693 - accuracy: 0.9734 - val_loss: 0.1855 - val_accuracy: 0.9638
# Epoch 22/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.0806 - accuracy: 0.9720 - val_loss: 0.2284 - val_accuracy: 0.9609
# Epoch 23/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.0721 - accuracy: 0.9746 - val_loss: 0.2135 - val_accuracy: 0.9605
# Epoch 24/50
# 178/178 [==============================] - 58s 323ms/step - loss: 0.0665 - accuracy: 0.9760 - val_loss: 0.1856 - val_accuracy: 0.9650
# Epoch 25/50
# 178/178 [==============================] - 59s 334ms/step - loss: 0.0665 - accuracy: 0.9787 - val_loss: 0.2045 - val_accuracy: 0.9601
# Epoch 26/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.0640 - accuracy: 0.9750 - val_loss: 0.1865 - val_accuracy: 0.9592
# Epoch 27/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.0617 - accuracy: 0.9788 - val_loss: 0.1886 - val_accuracy: 0.9609
# Epoch 28/50
# 178/178 [==============================] - 57s 322ms/step - loss: 0.0629 - accuracy: 0.9787 - val_loss: 0.2179 - val_accuracy: 0.9597
# Epoch 29/50
# 178/178 [==============================] - 61s 345ms/step - loss: 0.0512 - accuracy: 0.9834 - val_loss: 0.2280 - val_accuracy: 0.9625
# Epoch 30/50
# 178/178 [==============================] - 59s 331ms/step - loss: 0.0549 - accuracy: 0.9787 - val_loss: 0.2104 - val_accuracy: 0.9662
# Epoch 31/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.0497 - accuracy: 0.9848 - val_loss: 0.2762 - val_accuracy: 0.9609
# Epoch 32/50
# 178/178 [==============================] - 58s 323ms/step - loss: 0.0535 - accuracy: 0.9824 - val_loss: 0.2347 - val_accuracy: 0.9621
# Epoch 33/50
# 178/178 [==============================] - 59s 329ms/step - loss: 0.0581 - accuracy: 0.9820 - val_loss: 0.2772 - val_accuracy: 0.9555
# Epoch 34/50
# 178/178 [==============================] - 57s 322ms/step - loss: 0.0512 - accuracy: 0.9841 - val_loss: 0.2529 - val_accuracy: 0.9601
# Epoch 35/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.0471 - accuracy: 0.9863 - val_loss: 0.2757 - val_accuracy: 0.9531
# Epoch 36/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.0493 - accuracy: 0.9813 - val_loss: 0.2172 - val_accuracy: 0.9654
# Epoch 37/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.0493 - accuracy: 0.9843 - val_loss: 0.2502 - val_accuracy: 0.9650
# Epoch 38/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.0506 - accuracy: 0.9824 - val_loss: 0.2694 - val_accuracy: 0.9601
# Epoch 39/50
# 178/178 [==============================] - 57s 322ms/step - loss: 0.0568 - accuracy: 0.9836 - val_loss: 0.2302 - val_accuracy: 0.9617
# Epoch 40/50
# 178/178 [==============================] - 58s 323ms/step - loss: 0.0562 - accuracy: 0.9811 - val_loss: 0.2872 - val_accuracy: 0.9646
# Epoch 41/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.0432 - accuracy: 0.9848 - val_loss: 0.2072 - val_accuracy: 0.9625
# Epoch 42/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.0409 - accuracy: 0.9854 - val_loss: 0.3091 - val_accuracy: 0.9609
# Epoch 43/50
# 178/178 [==============================] - 58s 325ms/step - loss: 0.0443 - accuracy: 0.9863 - val_loss: 0.2675 - val_accuracy: 0.9592
# Epoch 44/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.0405 - accuracy: 0.9854 - val_loss: 0.3094 - val_accuracy: 0.9634
# Epoch 45/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.0456 - accuracy: 0.9863 - val_loss: 0.2942 - val_accuracy: 0.9584
# Epoch 46/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.0398 - accuracy: 0.9870 - val_loss: 0.3055 - val_accuracy: 0.9601
# Epoch 47/50
# 178/178 [==============================] - 58s 325ms/step - loss: 0.0418 - accuracy: 0.9859 - val_loss: 0.2734 - val_accuracy: 0.9625
# Epoch 48/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.0415 - accuracy: 0.9880 - val_loss: 0.2151 - val_accuracy: 0.9671
# Epoch 49/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.0414 - accuracy: 0.9873 - val_loss: 0.2693 - val_accuracy: 0.9597
# Epoch 50/50
# 178/178 [==============================] - 58s 325ms/step - loss: 0.0462 - accuracy: 0.9868 - val_loss: 0.3409 - val_accuracy: 0.9638
# 76/76 [==============================] - 17s 227ms/step - loss: 0.3409 - accuracy: 0.9638
# Accuracy on the Test Set = 96.38 %
# Model Saved!
# True :  [0 0 0 ... 4 4 4]
# 76/76 [==============================] - 18s 229ms/step
# Predicted :  [0 0 0 ... 4 4 4]
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_3 (Flatten)         (None, 25088)             0
#
#  dense_6 (Dense)             (None, 32)                802848
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 20,827,397
# Trainable params: 803,013
# Non-trainable params: 20,024,384
# _________________________________________________________________
# Epoch 1/50
# 178/178 [==============================] - 60s 327ms/step - loss: 1.7964 - accuracy: 0.5212 - val_loss: 0.5410 - val_accuracy: 0.7814
# Epoch 2/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.7550 - accuracy: 0.7037 - val_loss: 0.3439 - val_accuracy: 0.8666
# Epoch 3/50
# 178/178 [==============================] - 57s 322ms/step - loss: 0.5360 - accuracy: 0.7876 - val_loss: 0.2601 - val_accuracy: 0.9094
# Epoch 4/50
# 178/178 [==============================] - 61s 345ms/step - loss: 0.4564 - accuracy: 0.8317 - val_loss: 0.2194 - val_accuracy: 0.9247
# Epoch 5/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.3450 - accuracy: 0.8609 - val_loss: 0.2242 - val_accuracy: 0.9366
# Epoch 6/50
# 178/178 [==============================] - 62s 348ms/step - loss: 0.3303 - accuracy: 0.8613 - val_loss: 0.2053 - val_accuracy: 0.9415
# Epoch 7/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.2944 - accuracy: 0.8766 - val_loss: 0.1771 - val_accuracy: 0.9452
# Epoch 8/50
# 178/178 [==============================] - 60s 334ms/step - loss: 0.2794 - accuracy: 0.8763 - val_loss: 0.1720 - val_accuracy: 0.9444
# Epoch 9/50
# 178/178 [==============================] - 57s 322ms/step - loss: 0.2828 - accuracy: 0.8817 - val_loss: 0.1533 - val_accuracy: 0.9518
# Epoch 10/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.2525 - accuracy: 0.8882 - val_loss: 0.1750 - val_accuracy: 0.9535
# Epoch 11/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.2298 - accuracy: 0.8983 - val_loss: 0.1559 - val_accuracy: 0.9510
# Epoch 12/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.2346 - accuracy: 0.8965 - val_loss: 0.1678 - val_accuracy: 0.9551
# Epoch 13/50
# 178/178 [==============================] - 58s 325ms/step - loss: 0.2264 - accuracy: 0.9036 - val_loss: 0.1592 - val_accuracy: 0.9539
# Epoch 14/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.2069 - accuracy: 0.9043 - val_loss: 0.2083 - val_accuracy: 0.9584
# Epoch 15/50
# 178/178 [==============================] - 57s 322ms/step - loss: 0.1908 - accuracy: 0.9127 - val_loss: 0.1940 - val_accuracy: 0.9555
# Epoch 16/50
# 178/178 [==============================] - 61s 344ms/step - loss: 0.1962 - accuracy: 0.9059 - val_loss: 0.1879 - val_accuracy: 0.9588
# Epoch 17/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.1890 - accuracy: 0.9175 - val_loss: 0.1971 - val_accuracy: 0.9592
# Epoch 18/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.1826 - accuracy: 0.9163 - val_loss: 0.1923 - val_accuracy: 0.9601
# Epoch 19/50
# 178/178 [==============================] - 57s 322ms/step - loss: 0.1829 - accuracy: 0.9120 - val_loss: 0.1969 - val_accuracy: 0.9601
# Epoch 20/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.1855 - accuracy: 0.9096 - val_loss: 0.1948 - val_accuracy: 0.9650
# Epoch 21/50
# 178/178 [==============================] - 62s 347ms/step - loss: 0.1739 - accuracy: 0.9201 - val_loss: 0.2103 - val_accuracy: 0.9597
# Epoch 22/50
# 178/178 [==============================] - 59s 329ms/step - loss: 0.1806 - accuracy: 0.9119 - val_loss: 0.1805 - val_accuracy: 0.9576
# Epoch 23/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.1706 - accuracy: 0.9180 - val_loss: 0.1719 - val_accuracy: 0.9667
# Epoch 24/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.1464 - accuracy: 0.9295 - val_loss: 0.1870 - val_accuracy: 0.9650
# Epoch 25/50
# 178/178 [==============================] - 57s 323ms/step - loss: 0.1502 - accuracy: 0.9300 - val_loss: 0.1652 - val_accuracy: 0.9629
# Epoch 26/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.1526 - accuracy: 0.9300 - val_loss: 0.1763 - val_accuracy: 0.9646
# Epoch 27/50
# 178/178 [==============================] - 58s 326ms/step - loss: 0.1406 - accuracy: 0.9344 - val_loss: 0.2465 - val_accuracy: 0.9597
# Epoch 28/50
# 178/178 [==============================] - 59s 329ms/step - loss: 0.1499 - accuracy: 0.9334 - val_loss: 0.2184 - val_accuracy: 0.9646
# Epoch 29/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.1485 - accuracy: 0.9291 - val_loss: 0.2285 - val_accuracy: 0.9634
# Epoch 30/50
# 178/178 [==============================] - 58s 325ms/step - loss: 0.1452 - accuracy: 0.9279 - val_loss: 0.1874 - val_accuracy: 0.9662
# Epoch 31/50
# 178/178 [==============================] - 57s 322ms/step - loss: 0.1418 - accuracy: 0.9307 - val_loss: 0.1824 - val_accuracy: 0.9675
# Epoch 32/50
# 178/178 [==============================] - 62s 350ms/step - loss: 0.1572 - accuracy: 0.9219 - val_loss: 0.1768 - val_accuracy: 0.9654
# Epoch 33/50
# 178/178 [==============================] - 58s 323ms/step - loss: 0.1310 - accuracy: 0.9353 - val_loss: 0.1680 - val_accuracy: 0.9646
# Epoch 34/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.1276 - accuracy: 0.9365 - val_loss: 0.2035 - val_accuracy: 0.9642
# Epoch 35/50
# 178/178 [==============================] - 57s 321ms/step - loss: 0.1538 - accuracy: 0.9272 - val_loss: 0.2142 - val_accuracy: 0.9634
# Epoch 36/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.1515 - accuracy: 0.9316 - val_loss: 0.2285 - val_accuracy: 0.9638
# Epoch 37/50
# 178/178 [==============================] - 59s 329ms/step - loss: 0.1267 - accuracy: 0.9362 - val_loss: 0.2332 - val_accuracy: 0.9654
# Epoch 38/50
# 178/178 [==============================] - 61s 343ms/step - loss: 0.1351 - accuracy: 0.9374 - val_loss: 0.2166 - val_accuracy: 0.9667
# Epoch 39/50
# 178/178 [==============================] - 57s 322ms/step - loss: 0.1383 - accuracy: 0.9344 - val_loss: 0.1479 - val_accuracy: 0.9658
# Epoch 40/50
# 178/178 [==============================] - 58s 327ms/step - loss: 0.1415 - accuracy: 0.9300 - val_loss: 0.1923 - val_accuracy: 0.9650
# Epoch 41/50
# 178/178 [==============================] - 57s 322ms/step - loss: 0.1337 - accuracy: 0.9351 - val_loss: 0.1696 - val_accuracy: 0.9704
# Epoch 42/50
# 178/178 [==============================] - 59s 332ms/step - loss: 0.1104 - accuracy: 0.9436 - val_loss: 0.1743 - val_accuracy: 0.9720
# Epoch 43/50
# 178/178 [==============================] - 57s 322ms/step - loss: 0.1192 - accuracy: 0.9417 - val_loss: 0.1458 - val_accuracy: 0.9687
# Epoch 44/50
# 178/178 [==============================] - 58s 328ms/step - loss: 0.1172 - accuracy: 0.9441 - val_loss: 0.1847 - val_accuracy: 0.9716
# Epoch 45/50
# 178/178 [==============================] - 58s 323ms/step - loss: 0.1119 - accuracy: 0.9429 - val_loss: 0.2185 - val_accuracy: 0.9687
# Epoch 46/50
# 178/178 [==============================] - 58s 324ms/step - loss: 0.1260 - accuracy: 0.9387 - val_loss: 0.1998 - val_accuracy: 0.9679
